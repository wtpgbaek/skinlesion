# %% [markdown]
# ## **드라이브 마운트**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#%cd /content/drive/MyDrive/Classification

#%cd /content/drive/MyDrive/Classification_balanced_128

# %cd /content/drive/MyDrive/Classification_balanced_256
# Out:
# /content/drive/MyDrive/Classification_balanced_256

# %% [markdown]
# ## **필요 라이브러리 설치**

# %%
# !pip install tensorflow-addons==0.22.0
# Out:
# Collecting tensorflow-addons==0.22.0
#   Downloading tensorflow_addons-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.3/612.3 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons==0.22.0) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons==0.22.0)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.22.0 typeguard-2.13.3

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import os
import cv2
import numpy as np

from model_layer import * #모듈화한 모델 import
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder

import keras.backend as K
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# ## **Train, Validation, Test 데이터셋**

# %%
os.makedirs('checkpoints', exist_ok=True)

test1 = 0
test2 = 1
test3 = 2
test4 = 3
test5 = 4
level1=10
level2=20

file_name=[]

train = 0
val = 1
test = 2

def make_test_data(test1,level1, num):
  X=[]
  y=[]

  for f_label, folder_name in enumerate(('ACTINIC_KERATOSIS', 'BASAL_CELL_CARCINOMA', 'DERMATOFIBROMA', 'MELANOMA', 'NEVUS', 'PIGMENTED_BENIGN_KERATOSIS', 'SQUAMOUS_CELL_CARCIMONA','VASCULAR_LESION')):
    folder_path = os.path.join("./dataset_"+str(num)+"/", folder_name)
    print(folder_path)

    for fname in os.listdir(folder_path):
        fpath = os.path.join(folder_path, fname)
        if num == test:
          file_name.append(fpath)

        img = cv2.imread(fpath, cv2.IMREAD_COLOR)
        img = cv2.resize(img, image_shape[1:])

        X.append(img)
        y.append(f_label)

  X = np.array(X)
  y = np.array(y).reshape(-1, 1)

  X = (X / 255.)
  X = X.transpose(0, 3, 1, 2)
  X = X.astype(np.float32)
  y = y.astype(np.float32)

  x_train = X
  y_train = y
  return x_train, y_train

#image_shape = (3, 128, 128)
image_shape = (3, 256, 256)

x_train, y_train= make_test_data(test1,level1, train)
x_val, y_val= make_test_data(test1,level1, val)
x_test, y_test= make_test_data(test1,level1, test)

enc = OneHotEncoder(handle_unknown='ignore')
temp_y = enc.fit_transform(y_train).toarray()
y_train = temp_y

temp_y = enc.fit_transform(y_val).toarray()
y_val = temp_y
# Out:
# ./dataset_0/ACTINIC_KERATOSIS
# ./dataset_0/BASAL_CELL_CARCINOMA
# ./dataset_0/DERMATOFIBROMA
# ./dataset_0/MELANOMA
# ./dataset_0/NEVUS
# ./dataset_0/PIGMENTED_BENIGN_KERATOSIS
# ./dataset_0/SQUAMOUS_CELL_CARCIMONA
# ./dataset_0/VASCULAR_LESION
# ./dataset_1/ACTINIC_KERATOSIS
# ./dataset_1/BASAL_CELL_CARCINOMA
# ./dataset_1/DERMATOFIBROMA
# ./dataset_1/MELANOMA
# ./dataset_1/NEVUS
# ./dataset_1/PIGMENTED_BENIGN_KERATOSIS
# ./dataset_1/SQUAMOUS_CELL_CARCIMONA
# ./dataset_1/VASCULAR_LESION
# ./dataset_2/ACTINIC_KERATOSIS
# ./dataset_2/BASAL_CELL_CARCINOMA
# ./dataset_2/DERMATOFIBROMA
# ./dataset_2/MELANOMA
# ./dataset_2/NEVUS
# ./dataset_2/PIGMENTED_BENIGN_KERATOSIS
# ./dataset_2/SQUAMOUS_CELL_CARCIMONA
# ./dataset_2/VASCULAR_LESION

# %% [markdown]
# ## **모델 선언**

# %%
#make model
model = make_model(image_shape, num_classes=8)

epochs = 100
ckpoint= tf.keras.callbacks.ModelCheckpoint(filepath='./model_save/',monitor='val_f1_score',save_best_only=True, save_weights_only=True)
earlystopping= tf.keras.callbacks.EarlyStopping(monitor='val_f1_score', patience=10,mode='max')

precision = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()
auc = tf.keras.metrics.AUC()
spec=tf.keras.metrics.SpecificityAtSensitivity(0.5)
iou=tf.keras.metrics.MeanIoU(num_classes=8)
f1_score = tfa.metrics.F1Score(num_classes=8, threshold=0.6,average='micro')

learningrate=0.000007
batch = 8
opt1=tf.keras.optimizers.Adamax(learning_rate=learningrate)
opt3=tf.keras.optimizers.Adam(learning_rate=learningrate)
opt1=tf.keras.mixed_precision.LossScaleOptimizer(opt1)

# %% [markdown]
# ## **모델 학습**

# %%
losses  = 'mse'
model.compile(
        optimizer = opt1,
        loss = losses,
        metrics = [precision, recall, auc,f1_score,spec,iou]
)

hist = model.fit(x_train, y_train,epochs=epochs,batch_size=batch,validation_data = (x_val, y_val),
        callbacks = [ckpoint]
)

model.save("./model_save/classification256_model_"+str(test1)+"8_100.h5", include_optimizer=True)
# Out:
# Epoch 1/100
# 114/114 [==============================] - 45s 323ms/step - loss: 0.1092 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5386 - f1_score: 0.0000e+00 - specificity_at_sensitivity: 0.1427 - mean_io_u: 0.4375 - val_loss: 0.1094 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_f1_score: 0.0000e+00 - val_specificity_at_sensitivity: 0.0000e+00 - val_mean_io_u: 0.4375
# Epoch 2/100
# 114/114 [==============================] - 35s 309ms/step - loss: 0.1088 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6084 - f1_score: 0.0000e+00 - specificity_at_sensitivity: 0.6352 - mean_io_u: 0.4375 - val_loss: 0.1094 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5038 - val_f1_score: 0.0000e+00 - val_specificity_at_sensitivity: 0.0000e+00 - val_mean_io_u: 0.4375
# Epoch 3/100
# 114/114 [==============================] - 35s 307ms/step - loss: 0.1083 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6447 - f1_score: 0.0000e+00 - specificity_at_sensitivity: 0.6439 - mean_io_u: 0.4375 - val_loss: 0.1094 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5038 - val_f1_score: 0.0000e+00 - val_specificity_at_sensitivity: 0.0000e+00 - val_mean_io_u: 0.4375
# Epoch 4/100
# 114/114 [==============================] - 35s 306ms/step - loss: 0.1077 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6581 - f1_score: 0.0000e+00 - specificity_at_sensitivity: 0.6500 - mean_io_u: 0.4375 - val_loss: 0.1094 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5050 - val_f1_score: 0.0000e+00 - val_specificity_at_sensitivity: 0.0000e+00 - val_mean_io_u: 0.4375
# Epoch 5/100
# 114/114 [==============================] - 35s 307ms/step - loss: 0.1067 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6742 - f1_score: 0.0000e+00 - specificity_at_sensitivity: 0.6601 - mean_io_u: 0.4375 - val_loss: 0.1093 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5221 - val_f1_score: 0.0000e+00 - val_specificity_at_sensitivity: 0.0138 - val_mean_io_u: 0.4375
# Epoch 6/100
# 114/114 [==============================] - 35s 306ms/step - loss: 0.1054 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6857 - f1_score: 0.0000e+00 - specificity_at_sensitivity: 0.6767 - mean_io_u: 0.4375 - val_loss: 0.1085 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6023 - val_f1_score: 0.0000e+00 - val_specificity_at_sensitivity: 0.3697 - val_mean_io_u: 0.4375
# Epoch 7/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.1042 - precision: 1.0000 - recall: 0.0044 - auc: 0.6944 - f1_score: 0.0000e+00 - specificity_at_sensitivity: 0.6819 - mean_io_u: 0.4375 - val_loss: 0.1055 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6982 - val_f1_score: 0.0000e+00 - val_specificity_at_sensitivity: 0.6880 - val_mean_io_u: 0.4375
# Epoch 8/100
# 114/114 [==============================] - 35s 304ms/step - loss: 0.1033 - precision: 0.8696 - recall: 0.0220 - auc: 0.6949 - f1_score: 0.0066 - specificity_at_sensitivity: 0.6983 - mean_io_u: 0.4375 - val_loss: 0.1020 - val_precision: 0.8000 - val_recall: 0.0351 - val_auc: 0.7165 - val_f1_score: 0.0342 - val_specificity_at_sensitivity: 0.7882 - val_mean_io_u: 0.4375
# Epoch 9/100
# 114/114 [==============================] - 39s 337ms/step - loss: 0.1024 - precision: 0.8158 - recall: 0.0341 - auc: 0.7041 - f1_score: 0.0260 - specificity_at_sensitivity: 0.7589 - mean_io_u: 0.4375 - val_loss: 0.1005 - val_precision: 0.8462 - val_recall: 0.0965 - val_auc: 0.7242 - val_f1_score: 0.0992 - val_specificity_at_sensitivity: 0.7694 - val_mean_io_u: 0.4375
# Epoch 10/100
# 114/114 [==============================] - 36s 317ms/step - loss: 0.1016 - precision: 0.7872 - recall: 0.0407 - auc: 0.7096 - f1_score: 0.0429 - specificity_at_sensitivity: 0.7559 - mean_io_u: 0.4375 - val_loss: 0.0998 - val_precision: 0.7857 - val_recall: 0.0965 - val_auc: 0.7309 - val_f1_score: 0.1452 - val_specificity_at_sensitivity: 0.7581 - val_mean_io_u: 0.4375
# Epoch 11/100
# 114/114 [==============================] - 35s 309ms/step - loss: 0.1013 - precision: 0.7021 - recall: 0.0363 - auc: 0.7105 - f1_score: 0.0511 - specificity_at_sensitivity: 0.7536 - mean_io_u: 0.4375 - val_loss: 0.0992 - val_precision: 0.7857 - val_recall: 0.0965 - val_auc: 0.7343 - val_f1_score: 0.1732 - val_specificity_at_sensitivity: 0.7957 - val_mean_io_u: 0.4375
# Epoch 12/100
# 114/114 [==============================] - 35s 306ms/step - loss: 0.1002 - precision: 0.7778 - recall: 0.0462 - auc: 0.7180 - f1_score: 0.0655 - specificity_at_sensitivity: 0.7467 - mean_io_u: 0.4375 - val_loss: 0.0983 - val_precision: 0.7857 - val_recall: 0.0965 - val_auc: 0.7443 - val_f1_score: 0.1587 - val_specificity_at_sensitivity: 0.8233 - val_mean_io_u: 0.4375
# Epoch 13/100
# 114/114 [==============================] - 35s 304ms/step - loss: 0.0999 - precision: 0.7727 - recall: 0.0561 - auc: 0.7113 - f1_score: 0.0736 - specificity_at_sensitivity: 0.7474 - mean_io_u: 0.4375 - val_loss: 0.0985 - val_precision: 0.7500 - val_recall: 0.1053 - val_auc: 0.7392 - val_f1_score: 0.1719 - val_specificity_at_sensitivity: 0.7907 - val_mean_io_u: 0.4375
# Epoch 14/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.0986 - precision: 0.8000 - recall: 0.0616 - auc: 0.7314 - f1_score: 0.0781 - specificity_at_sensitivity: 0.7828 - mean_io_u: 0.4375 - val_loss: 0.0975 - val_precision: 0.8000 - val_recall: 0.1053 - val_auc: 0.7474 - val_f1_score: 0.1732 - val_specificity_at_sensitivity: 0.8333 - val_mean_io_u: 0.4375
# Epoch 15/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.0984 - precision: 0.7917 - recall: 0.0627 - auc: 0.7331 - f1_score: 0.0879 - specificity_at_sensitivity: 0.7759 - mean_io_u: 0.4375 - val_loss: 0.0962 - val_precision: 0.7857 - val_recall: 0.0965 - val_auc: 0.7601 - val_f1_score: 0.1587 - val_specificity_at_sensitivity: 0.8233 - val_mean_io_u: 0.4375
# Epoch 16/100
# 114/114 [==============================] - 35s 305ms/step - loss: 0.0985 - precision: 0.7671 - recall: 0.0616 - auc: 0.7279 - f1_score: 0.0775 - specificity_at_sensitivity: 0.7710 - mean_io_u: 0.4375 - val_loss: 0.0960 - val_precision: 0.7857 - val_recall: 0.0965 - val_auc: 0.7586 - val_f1_score: 0.1587 - val_specificity_at_sensitivity: 0.8208 - val_mean_io_u: 0.4375
# Epoch 17/100
# 114/114 [==============================] - 36s 311ms/step - loss: 0.0982 - precision: 0.7662 - recall: 0.0649 - auc: 0.7348 - f1_score: 0.0818 - specificity_at_sensitivity: 0.7937 - mean_io_u: 0.4375 - val_loss: 0.0954 - val_precision: 0.7857 - val_recall: 0.0965 - val_auc: 0.7605 - val_f1_score: 0.1587 - val_specificity_at_sensitivity: 0.8233 - val_mean_io_u: 0.4375
# Epoch 18/100
# 114/114 [==============================] - 35s 305ms/step - loss: 0.0974 - precision: 0.7500 - recall: 0.0726 - auc: 0.7406 - f1_score: 0.0912 - specificity_at_sensitivity: 0.7875 - mean_io_u: 0.4375 - val_loss: 0.0955 - val_precision: 0.8125 - val_recall: 0.1140 - val_auc: 0.7572 - val_f1_score: 0.1719 - val_specificity_at_sensitivity: 0.8158 - val_mean_io_u: 0.4375
# Epoch 19/100
# 114/114 [==============================] - 36s 312ms/step - loss: 0.0969 - precision: 0.7326 - recall: 0.0693 - auc: 0.7452 - f1_score: 0.0916 - specificity_at_sensitivity: 0.8113 - mean_io_u: 0.4375 - val_loss: 0.0951 - val_precision: 0.8125 - val_recall: 0.1140 - val_auc: 0.7596 - val_f1_score: 0.1719 - val_specificity_at_sensitivity: 0.8108 - val_mean_io_u: 0.4375
# Epoch 20/100
# 114/114 [==============================] - 35s 307ms/step - loss: 0.0971 - precision: 0.7684 - recall: 0.0803 - auc: 0.7448 - f1_score: 0.1070 - specificity_at_sensitivity: 0.7834 - mean_io_u: 0.4375 - val_loss: 0.0947 - val_precision: 0.8125 - val_recall: 0.1140 - val_auc: 0.7620 - val_f1_score: 0.1719 - val_specificity_at_sensitivity: 0.8095 - val_mean_io_u: 0.4375
# Epoch 21/100
# 114/114 [==============================] - 35s 304ms/step - loss: 0.0960 - precision: 0.7895 - recall: 0.0825 - auc: 0.7519 - f1_score: 0.1073 - specificity_at_sensitivity: 0.8205 - mean_io_u: 0.4375 - val_loss: 0.0943 - val_precision: 0.8125 - val_recall: 0.1140 - val_auc: 0.7672 - val_f1_score: 0.1732 - val_specificity_at_sensitivity: 0.8070 - val_mean_io_u: 0.4375
# Epoch 22/100
# 114/114 [==============================] - 39s 344ms/step - loss: 0.0971 - precision: 0.7188 - recall: 0.0759 - auc: 0.7409 - f1_score: 0.0992 - specificity_at_sensitivity: 0.7940 - mean_io_u: 0.4375 - val_loss: 0.0944 - val_precision: 0.8235 - val_recall: 0.1228 - val_auc: 0.7646 - val_f1_score: 0.1719 - val_specificity_at_sensitivity: 0.8170 - val_mean_io_u: 0.4375
# Epoch 23/100
# 114/114 [==============================] - 36s 316ms/step - loss: 0.0962 - precision: 0.7849 - recall: 0.0803 - auc: 0.7478 - f1_score: 0.0894 - specificity_at_sensitivity: 0.8282 - mean_io_u: 0.4375 - val_loss: 0.0945 - val_precision: 0.7368 - val_recall: 0.1228 - val_auc: 0.7626 - val_f1_score: 0.1860 - val_specificity_at_sensitivity: 0.8120 - val_mean_io_u: 0.4375
# Epoch 24/100
# 114/114 [==============================] - 36s 319ms/step - loss: 0.0962 - precision: 0.7368 - recall: 0.0770 - auc: 0.7545 - f1_score: 0.1014 - specificity_at_sensitivity: 0.8120 - mean_io_u: 0.4375 - val_loss: 0.0949 - val_precision: 0.7368 - val_recall: 0.1228 - val_auc: 0.7612 - val_f1_score: 0.1860 - val_specificity_at_sensitivity: 0.8120 - val_mean_io_u: 0.4375
# Epoch 25/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.0959 - precision: 0.7476 - recall: 0.0847 - auc: 0.7590 - f1_score: 0.0929 - specificity_at_sensitivity: 0.8246 - mean_io_u: 0.4375 - val_loss: 0.0935 - val_precision: 0.7778 - val_recall: 0.1228 - val_auc: 0.7738 - val_f1_score: 0.1587 - val_specificity_at_sensitivity: 0.8383 - val_mean_io_u: 0.4375
# Epoch 26/100
# 114/114 [==============================] - 35s 310ms/step - loss: 0.0964 - precision: 0.7200 - recall: 0.0792 - auc: 0.7504 - f1_score: 0.1067 - specificity_at_sensitivity: 0.8223 - mean_io_u: 0.4375 - val_loss: 0.0935 - val_precision: 0.7778 - val_recall: 0.1228 - val_auc: 0.7719 - val_f1_score: 0.1732 - val_specificity_at_sensitivity: 0.8358 - val_mean_io_u: 0.4375
# Epoch 27/100
# 114/114 [==============================] - 35s 309ms/step - loss: 0.0952 - precision: 0.7263 - recall: 0.0759 - auc: 0.7642 - f1_score: 0.1132 - specificity_at_sensitivity: 0.8168 - mean_io_u: 0.4375 - val_loss: 0.0941 - val_precision: 0.7368 - val_recall: 0.1228 - val_auc: 0.7699 - val_f1_score: 0.1860 - val_specificity_at_sensitivity: 0.8333 - val_mean_io_u: 0.4375
# Epoch 28/100
# 114/114 [==============================] - 36s 317ms/step - loss: 0.0952 - precision: 0.7238 - recall: 0.0836 - auc: 0.7613 - f1_score: 0.1223 - specificity_at_sensitivity: 0.8298 - mean_io_u: 0.4375 - val_loss: 0.0938 - val_precision: 0.7368 - val_recall: 0.1228 - val_auc: 0.7707 - val_f1_score: 0.1860 - val_specificity_at_sensitivity: 0.8308 - val_mean_io_u: 0.4375
# Epoch 29/100
# 114/114 [==============================] - 35s 308ms/step - loss: 0.0953 - precision: 0.7475 - recall: 0.0814 - auc: 0.7608 - f1_score: 0.1049 - specificity_at_sensitivity: 0.8265 - mean_io_u: 0.4375 - val_loss: 0.0942 - val_precision: 0.7000 - val_recall: 0.1228 - val_auc: 0.7681 - val_f1_score: 0.1860 - val_specificity_at_sensitivity: 0.8246 - val_mean_io_u: 0.4375
# Epoch 30/100
# 114/114 [==============================] - 36s 314ms/step - loss: 0.0944 - precision: 0.7890 - recall: 0.0946 - auc: 0.7648 - f1_score: 0.1192 - specificity_at_sensitivity: 0.8276 - mean_io_u: 0.4375 - val_loss: 0.0937 - val_precision: 0.7000 - val_recall: 0.1228 - val_auc: 0.7749 - val_f1_score: 0.1732 - val_specificity_at_sensitivity: 0.8333 - val_mean_io_u: 0.4375
# Epoch 31/100
# 114/114 [==============================] - 35s 308ms/step - loss: 0.0944 - precision: 0.7714 - recall: 0.0891 - auc: 0.7662 - f1_score: 0.1148 - specificity_at_sensitivity: 0.8417 - mean_io_u: 0.4375 - val_loss: 0.0937 - val_precision: 0.7000 - val_recall: 0.1228 - val_auc: 0.7751 - val_f1_score: 0.1875 - val_specificity_at_sensitivity: 0.8321 - val_mean_io_u: 0.4375
# Epoch 32/100
# 114/114 [==============================] - 35s 305ms/step - loss: 0.0936 - precision: 0.7381 - recall: 0.1023 - auc: 0.7722 - f1_score: 0.1284 - specificity_at_sensitivity: 0.8402 - mean_io_u: 0.4375 - val_loss: 0.0931 - val_precision: 0.7895 - val_recall: 0.1316 - val_auc: 0.7804 - val_f1_score: 0.1587 - val_specificity_at_sensitivity: 0.8609 - val_mean_io_u: 0.4375
# Epoch 33/100
# 114/114 [==============================] - 36s 312ms/step - loss: 0.0936 - precision: 0.7302 - recall: 0.1012 - auc: 0.7692 - f1_score: 0.1260 - specificity_at_sensitivity: 0.8388 - mean_io_u: 0.4375 - val_loss: 0.0926 - val_precision: 0.7895 - val_recall: 0.1316 - val_auc: 0.7799 - val_f1_score: 0.1587 - val_specificity_at_sensitivity: 0.8421 - val_mean_io_u: 0.4375
# Epoch 34/100
# 114/114 [==============================] - 38s 334ms/step - loss: 0.0933 - precision: 0.7627 - recall: 0.0990 - auc: 0.7745 - f1_score: 0.1244 - specificity_at_sensitivity: 0.8331 - mean_io_u: 0.4375 - val_loss: 0.0925 - val_precision: 0.7895 - val_recall: 0.1316 - val_auc: 0.7825 - val_f1_score: 0.1587 - val_specificity_at_sensitivity: 0.8484 - val_mean_io_u: 0.4375
# Epoch 35/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.0938 - precision: 0.7593 - recall: 0.0902 - auc: 0.7689 - f1_score: 0.1226 - specificity_at_sensitivity: 0.8301 - mean_io_u: 0.4375 - val_loss: 0.0921 - val_precision: 0.8500 - val_recall: 0.1491 - val_auc: 0.7836 - val_f1_score: 0.1732 - val_specificity_at_sensitivity: 0.8546 - val_mean_io_u: 0.4375
# Epoch 36/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.0939 - precision: 0.7360 - recall: 0.1012 - auc: 0.7684 - f1_score: 0.1192 - specificity_at_sensitivity: 0.8383 - mean_io_u: 0.4375 - val_loss: 0.0927 - val_precision: 0.7143 - val_recall: 0.1316 - val_auc: 0.7822 - val_f1_score: 0.1875 - val_specificity_at_sensitivity: 0.8358 - val_mean_io_u: 0.4375
# Epoch 37/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.0932 - precision: 0.7402 - recall: 0.1034 - auc: 0.7718 - f1_score: 0.1283 - specificity_at_sensitivity: 0.8529 - mean_io_u: 0.4375 - val_loss: 0.0920 - val_precision: 0.8000 - val_recall: 0.1404 - val_auc: 0.7868 - val_f1_score: 0.1587 - val_specificity_at_sensitivity: 0.8609 - val_mean_io_u: 0.4375
# Epoch 38/100
# 114/114 [==============================] - 35s 309ms/step - loss: 0.0930 - precision: 0.7583 - recall: 0.1001 - auc: 0.7729 - f1_score: 0.1265 - specificity_at_sensitivity: 0.8457 - mean_io_u: 0.4375 - val_loss: 0.0922 - val_precision: 0.7895 - val_recall: 0.1316 - val_auc: 0.7853 - val_f1_score: 0.1732 - val_specificity_at_sensitivity: 0.8571 - val_mean_io_u: 0.4375
# Epoch 39/100
# 114/114 [==============================] - 35s 308ms/step - loss: 0.0925 - precision: 0.8045 - recall: 0.1177 - auc: 0.7757 - f1_score: 0.1434 - specificity_at_sensitivity: 0.8507 - mean_io_u: 0.4375 - val_loss: 0.0922 - val_precision: 0.7619 - val_recall: 0.1404 - val_auc: 0.7824 - val_f1_score: 0.2016 - val_specificity_at_sensitivity: 0.8459 - val_mean_io_u: 0.4375
# Epoch 40/100
# 114/114 [==============================] - 36s 312ms/step - loss: 0.0923 - precision: 0.7323 - recall: 0.1023 - auc: 0.7810 - f1_score: 0.1354 - specificity_at_sensitivity: 0.8540 - mean_io_u: 0.4375 - val_loss: 0.0923 - val_precision: 0.6957 - val_recall: 0.1404 - val_auc: 0.7849 - val_f1_score: 0.2016 - val_specificity_at_sensitivity: 0.8434 - val_mean_io_u: 0.4375
# Epoch 41/100
# 114/114 [==============================] - 36s 315ms/step - loss: 0.0923 - precision: 0.7698 - recall: 0.1067 - auc: 0.7767 - f1_score: 0.1447 - specificity_at_sensitivity: 0.8619 - mean_io_u: 0.4375 - val_loss: 0.0918 - val_precision: 0.7391 - val_recall: 0.1491 - val_auc: 0.7869 - val_f1_score: 0.1732 - val_specificity_at_sensitivity: 0.8647 - val_mean_io_u: 0.4375
# Epoch 42/100
# 114/114 [==============================] - 35s 308ms/step - loss: 0.0918 - precision: 0.7943 - recall: 0.1232 - auc: 0.7763 - f1_score: 0.1545 - specificity_at_sensitivity: 0.8505 - mean_io_u: 0.4375 - val_loss: 0.0920 - val_precision: 0.6957 - val_recall: 0.1404 - val_auc: 0.7867 - val_f1_score: 0.2016 - val_specificity_at_sensitivity: 0.8559 - val_mean_io_u: 0.4375
# Epoch 43/100
# 114/114 [==============================] - 36s 315ms/step - loss: 0.0923 - precision: 0.7388 - recall: 0.1089 - auc: 0.7768 - f1_score: 0.1279 - specificity_at_sensitivity: 0.8504 - mean_io_u: 0.4375 - val_loss: 0.0913 - val_precision: 0.7391 - val_recall: 0.1491 - val_auc: 0.7898 - val_f1_score: 0.2016 - val_specificity_at_sensitivity: 0.8634 - val_mean_io_u: 0.4375
# Epoch 44/100
# 114/114 [==============================] - 35s 309ms/step - loss: 0.0915 - precision: 0.7552 - recall: 0.1188 - auc: 0.7828 - f1_score: 0.1384 - specificity_at_sensitivity: 0.8576 - mean_io_u: 0.4375 - val_loss: 0.0912 - val_precision: 0.7727 - val_recall: 0.1491 - val_auc: 0.7893 - val_f1_score: 0.2016 - val_specificity_at_sensitivity: 0.8659 - val_mean_io_u: 0.4375
# Epoch 45/100
# 114/114 [==============================] - 36s 314ms/step - loss: 0.0922 - precision: 0.7612 - recall: 0.1122 - auc: 0.7780 - f1_score: 0.1414 - specificity_at_sensitivity: 0.8515 - mean_io_u: 0.4375 - val_loss: 0.0919 - val_precision: 0.6957 - val_recall: 0.1404 - val_auc: 0.7868 - val_f1_score: 0.2000 - val_specificity_at_sensitivity: 0.8308 - val_mean_io_u: 0.4375
# Epoch 46/100
# 114/114 [==============================] - 36s 315ms/step - loss: 0.0916 - precision: 0.7929 - recall: 0.1221 - auc: 0.7844 - f1_score: 0.1378 - specificity_at_sensitivity: 0.8527 - mean_io_u: 0.4375 - val_loss: 0.0911 - val_precision: 0.7619 - val_recall: 0.1404 - val_auc: 0.7920 - val_f1_score: 0.2000 - val_specificity_at_sensitivity: 0.8584 - val_mean_io_u: 0.4375
# Epoch 47/100
# 114/114 [==============================] - 36s 315ms/step - loss: 0.0907 - precision: 0.8028 - recall: 0.1254 - auc: 0.7911 - f1_score: 0.1469 - specificity_at_sensitivity: 0.8586 - mean_io_u: 0.4375 - val_loss: 0.0911 - val_precision: 0.7083 - val_recall: 0.1491 - val_auc: 0.7947 - val_f1_score: 0.2000 - val_specificity_at_sensitivity: 0.8659 - val_mean_io_u: 0.4375
# Epoch 48/100
# 114/114 [==============================] - 35s 304ms/step - loss: 0.0917 - precision: 0.7551 - recall: 0.1221 - auc: 0.7815 - f1_score: 0.1575 - specificity_at_sensitivity: 0.8570 - mean_io_u: 0.4375 - val_loss: 0.0912 - val_precision: 0.7391 - val_recall: 0.1491 - val_auc: 0.7941 - val_f1_score: 0.2273 - val_specificity_at_sensitivity: 0.8659 - val_mean_io_u: 0.4375
# Epoch 49/100
# 114/114 [==============================] - 36s 315ms/step - loss: 0.0898 - precision: 0.8102 - recall: 0.1221 - auc: 0.7901 - f1_score: 0.1602 - specificity_at_sensitivity: 0.8664 - mean_io_u: 0.4375 - val_loss: 0.0910 - val_precision: 0.7500 - val_recall: 0.1316 - val_auc: 0.7934 - val_f1_score: 0.2000 - val_specificity_at_sensitivity: 0.8546 - val_mean_io_u: 0.4375
# Epoch 50/100
# 114/114 [==============================] - 35s 307ms/step - loss: 0.0895 - precision: 0.8025 - recall: 0.1430 - auc: 0.7951 - f1_score: 0.1807 - specificity_at_sensitivity: 0.8680 - mean_io_u: 0.4375 - val_loss: 0.0902 - val_precision: 0.7500 - val_recall: 0.1316 - val_auc: 0.7981 - val_f1_score: 0.2137 - val_specificity_at_sensitivity: 0.8571 - val_mean_io_u: 0.4375
# Epoch 51/100
# 114/114 [==============================] - 36s 312ms/step - loss: 0.0897 - precision: 0.7950 - recall: 0.1408 - auc: 0.7928 - f1_score: 0.1698 - specificity_at_sensitivity: 0.8644 - mean_io_u: 0.4375 - val_loss: 0.0902 - val_precision: 0.7500 - val_recall: 0.1316 - val_auc: 0.7986 - val_f1_score: 0.2137 - val_specificity_at_sensitivity: 0.8546 - val_mean_io_u: 0.4375
# Epoch 52/100
# 114/114 [==============================] - 35s 305ms/step - loss: 0.0896 - precision: 0.7750 - recall: 0.1364 - auc: 0.7943 - f1_score: 0.1566 - specificity_at_sensitivity: 0.8727 - mean_io_u: 0.4375 - val_loss: 0.0898 - val_precision: 0.7143 - val_recall: 0.1316 - val_auc: 0.8021 - val_f1_score: 0.2137 - val_specificity_at_sensitivity: 0.8722 - val_mean_io_u: 0.4375
# Epoch 53/100
# 114/114 [==============================] - 36s 314ms/step - loss: 0.0900 - precision: 0.8012 - recall: 0.1419 - auc: 0.7869 - f1_score: 0.1690 - specificity_at_sensitivity: 0.8733 - mean_io_u: 0.4375 - val_loss: 0.0896 - val_precision: 0.6957 - val_recall: 0.1404 - val_auc: 0.8046 - val_f1_score: 0.2000 - val_specificity_at_sensitivity: 0.8759 - val_mean_io_u: 0.4375
# Epoch 54/100
# 114/114 [==============================] - 35s 305ms/step - loss: 0.0888 - precision: 0.8084 - recall: 0.1485 - auc: 0.7964 - f1_score: 0.1798 - specificity_at_sensitivity: 0.8809 - mean_io_u: 0.4375 - val_loss: 0.0894 - val_precision: 0.6667 - val_recall: 0.1404 - val_auc: 0.8055 - val_f1_score: 0.2273 - val_specificity_at_sensitivity: 0.8659 - val_mean_io_u: 0.4375
# Epoch 55/100
# 114/114 [==============================] - 35s 303ms/step - loss: 0.0896 - precision: 0.7543 - recall: 0.1452 - auc: 0.7932 - f1_score: 0.1759 - specificity_at_sensitivity: 0.8716 - mean_io_u: 0.4375 - val_loss: 0.0892 - val_precision: 0.7083 - val_recall: 0.1491 - val_auc: 0.8085 - val_f1_score: 0.2137 - val_specificity_at_sensitivity: 0.8747 - val_mean_io_u: 0.4375
# Epoch 56/100
# 114/114 [==============================] - 35s 303ms/step - loss: 0.0886 - precision: 0.8187 - recall: 0.1540 - auc: 0.7993 - f1_score: 0.1748 - specificity_at_sensitivity: 0.8730 - mean_io_u: 0.4375 - val_loss: 0.0892 - val_precision: 0.6957 - val_recall: 0.1404 - val_auc: 0.8090 - val_f1_score: 0.2273 - val_specificity_at_sensitivity: 0.8822 - val_mean_io_u: 0.4375
# Epoch 57/100
# 114/114 [==============================] - 36s 312ms/step - loss: 0.0877 - precision: 0.7835 - recall: 0.1672 - auc: 0.8026 - f1_score: 0.1990 - specificity_at_sensitivity: 0.8908 - mean_io_u: 0.4375 - val_loss: 0.0888 - val_precision: 0.7083 - val_recall: 0.1491 - val_auc: 0.8134 - val_f1_score: 0.2000 - val_specificity_at_sensitivity: 0.8772 - val_mean_io_u: 0.4375
# Epoch 58/100
# 114/114 [==============================] - 35s 306ms/step - loss: 0.0886 - precision: 0.7889 - recall: 0.1562 - auc: 0.7989 - f1_score: 0.1879 - specificity_at_sensitivity: 0.8845 - mean_io_u: 0.4375 - val_loss: 0.0886 - val_precision: 0.6957 - val_recall: 0.1404 - val_auc: 0.8128 - val_f1_score: 0.2273 - val_specificity_at_sensitivity: 0.8772 - val_mean_io_u: 0.4375
# Epoch 59/100
# 114/114 [==============================] - 37s 322ms/step - loss: 0.0877 - precision: 0.8172 - recall: 0.1672 - auc: 0.8030 - f1_score: 0.2010 - specificity_at_sensitivity: 0.8707 - mean_io_u: 0.4375 - val_loss: 0.0879 - val_precision: 0.6667 - val_recall: 0.1404 - val_auc: 0.8167 - val_f1_score: 0.2406 - val_specificity_at_sensitivity: 0.8722 - val_mean_io_u: 0.4375
# Epoch 60/100
# 114/114 [==============================] - 35s 307ms/step - loss: 0.0865 - precision: 0.7980 - recall: 0.1782 - auc: 0.8110 - f1_score: 0.1994 - specificity_at_sensitivity: 0.8897 - mean_io_u: 0.4375 - val_loss: 0.0877 - val_precision: 0.6538 - val_recall: 0.1491 - val_auc: 0.8180 - val_f1_score: 0.2406 - val_specificity_at_sensitivity: 0.8897 - val_mean_io_u: 0.4375
# Epoch 61/100
# 114/114 [==============================] - 35s 309ms/step - loss: 0.0866 - precision: 0.7914 - recall: 0.1628 - auc: 0.8126 - f1_score: 0.2082 - specificity_at_sensitivity: 0.8868 - mean_io_u: 0.4375 - val_loss: 0.0878 - val_precision: 0.6667 - val_recall: 0.1579 - val_auc: 0.8176 - val_f1_score: 0.2406 - val_specificity_at_sensitivity: 0.8910 - val_mean_io_u: 0.4375
# Epoch 62/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.0867 - precision: 0.7772 - recall: 0.1650 - auc: 0.8089 - f1_score: 0.2126 - specificity_at_sensitivity: 0.8925 - mean_io_u: 0.4375 - val_loss: 0.0870 - val_precision: 0.6923 - val_recall: 0.1579 - val_auc: 0.8241 - val_f1_score: 0.2406 - val_specificity_at_sensitivity: 0.8847 - val_mean_io_u: 0.4375
# Epoch 63/100
# 114/114 [==============================] - 35s 312ms/step - loss: 0.0874 - precision: 0.7876 - recall: 0.1672 - auc: 0.8019 - f1_score: 0.2192 - specificity_at_sensitivity: 0.8663 - mean_io_u: 0.4375 - val_loss: 0.0869 - val_precision: 0.6207 - val_recall: 0.1579 - val_auc: 0.8228 - val_f1_score: 0.2406 - val_specificity_at_sensitivity: 0.8922 - val_mean_io_u: 0.4375
# Epoch 64/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.0864 - precision: 0.7933 - recall: 0.1815 - auc: 0.8087 - f1_score: 0.2252 - specificity_at_sensitivity: 0.8912 - mean_io_u: 0.4375 - val_loss: 0.0866 - val_precision: 0.6154 - val_recall: 0.1404 - val_auc: 0.8236 - val_f1_score: 0.2406 - val_specificity_at_sensitivity: 0.8910 - val_mean_io_u: 0.4375
# Epoch 65/100
# 114/114 [==============================] - 35s 310ms/step - loss: 0.0860 - precision: 0.7685 - recall: 0.1826 - auc: 0.8115 - f1_score: 0.2348 - specificity_at_sensitivity: 0.8938 - mean_io_u: 0.4375 - val_loss: 0.0859 - val_precision: 0.6897 - val_recall: 0.1754 - val_auc: 0.8273 - val_f1_score: 0.2406 - val_specificity_at_sensitivity: 0.9048 - val_mean_io_u: 0.4375
# Epoch 66/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.0866 - precision: 0.7523 - recall: 0.1771 - auc: 0.8078 - f1_score: 0.2262 - specificity_at_sensitivity: 0.8912 - mean_io_u: 0.4375 - val_loss: 0.0858 - val_precision: 0.6786 - val_recall: 0.1667 - val_auc: 0.8287 - val_f1_score: 0.2406 - val_specificity_at_sensitivity: 0.9035 - val_mean_io_u: 0.4375
# Epoch 67/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.0847 - precision: 0.7623 - recall: 0.1870 - auc: 0.8206 - f1_score: 0.2410 - specificity_at_sensitivity: 0.9048 - mean_io_u: 0.4375 - val_loss: 0.0855 - val_precision: 0.6786 - val_recall: 0.1667 - val_auc: 0.8294 - val_f1_score: 0.2406 - val_specificity_at_sensitivity: 0.9035 - val_mean_io_u: 0.4375
# Epoch 68/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.0856 - precision: 0.7668 - recall: 0.1881 - auc: 0.8149 - f1_score: 0.2455 - specificity_at_sensitivity: 0.8964 - mean_io_u: 0.4375 - val_loss: 0.0848 - val_precision: 0.7143 - val_recall: 0.1754 - val_auc: 0.8318 - val_f1_score: 0.2016 - val_specificity_at_sensitivity: 0.9085 - val_mean_io_u: 0.4375
# Epoch 69/100
# 114/114 [==============================] - 35s 310ms/step - loss: 0.0860 - precision: 0.8155 - recall: 0.1848 - auc: 0.8094 - f1_score: 0.2362 - specificity_at_sensitivity: 0.8887 - mean_io_u: 0.4375 - val_loss: 0.0850 - val_precision: 0.7000 - val_recall: 0.1842 - val_auc: 0.8302 - val_f1_score: 0.2406 - val_specificity_at_sensitivity: 0.9023 - val_mean_io_u: 0.4375
# Epoch 70/100
# 114/114 [==============================] - 35s 309ms/step - loss: 0.0848 - precision: 0.7851 - recall: 0.1969 - auc: 0.8232 - f1_score: 0.2535 - specificity_at_sensitivity: 0.8942 - mean_io_u: 0.4375 - val_loss: 0.0842 - val_precision: 0.7419 - val_recall: 0.2018 - val_auc: 0.8325 - val_f1_score: 0.2556 - val_specificity_at_sensitivity: 0.9035 - val_mean_io_u: 0.4375
# Epoch 71/100
# 114/114 [==============================] - 38s 338ms/step - loss: 0.0838 - precision: 0.8018 - recall: 0.2002 - auc: 0.8205 - f1_score: 0.2566 - specificity_at_sensitivity: 0.9068 - mean_io_u: 0.4375 - val_loss: 0.0842 - val_precision: 0.7000 - val_recall: 0.1842 - val_auc: 0.8344 - val_f1_score: 0.2556 - val_specificity_at_sensitivity: 0.9173 - val_mean_io_u: 0.4375
# Epoch 72/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.0849 - precision: 0.7769 - recall: 0.2068 - auc: 0.8191 - f1_score: 0.2601 - specificity_at_sensitivity: 0.8993 - mean_io_u: 0.4375 - val_loss: 0.0838 - val_precision: 0.7333 - val_recall: 0.1930 - val_auc: 0.8349 - val_f1_score: 0.2388 - val_specificity_at_sensitivity: 0.9098 - val_mean_io_u: 0.4375
# Epoch 73/100
# 114/114 [==============================] - 35s 310ms/step - loss: 0.0840 - precision: 0.7957 - recall: 0.2057 - auc: 0.8246 - f1_score: 0.2656 - specificity_at_sensitivity: 0.9084 - mean_io_u: 0.4375 - val_loss: 0.0838 - val_precision: 0.6875 - val_recall: 0.1930 - val_auc: 0.8345 - val_f1_score: 0.2537 - val_specificity_at_sensitivity: 0.9085 - val_mean_io_u: 0.4375
# Epoch 74/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.0839 - precision: 0.7860 - recall: 0.2101 - auc: 0.8239 - f1_score: 0.2591 - specificity_at_sensitivity: 0.8996 - mean_io_u: 0.4375 - val_loss: 0.0839 - val_precision: 0.6667 - val_recall: 0.1930 - val_auc: 0.8349 - val_f1_score: 0.2537 - val_specificity_at_sensitivity: 0.9010 - val_mean_io_u: 0.4375
# Epoch 75/100
# 114/114 [==============================] - 35s 308ms/step - loss: 0.0841 - precision: 0.7819 - recall: 0.2090 - auc: 0.8220 - f1_score: 0.2605 - specificity_at_sensitivity: 0.9013 - mean_io_u: 0.4375 - val_loss: 0.0844 - val_precision: 0.6765 - val_recall: 0.2018 - val_auc: 0.8314 - val_f1_score: 0.2519 - val_specificity_at_sensitivity: 0.9023 - val_mean_io_u: 0.4375
# Epoch 76/100
# 114/114 [==============================] - 36s 318ms/step - loss: 0.0844 - precision: 0.7948 - recall: 0.2002 - auc: 0.8222 - f1_score: 0.2669 - specificity_at_sensitivity: 0.8919 - mean_io_u: 0.4375 - val_loss: 0.0832 - val_precision: 0.7576 - val_recall: 0.2193 - val_auc: 0.8385 - val_f1_score: 0.2537 - val_specificity_at_sensitivity: 0.9110 - val_mean_io_u: 0.4375
# Epoch 77/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.0845 - precision: 0.7875 - recall: 0.2079 - auc: 0.8208 - f1_score: 0.2766 - specificity_at_sensitivity: 0.8895 - mean_io_u: 0.4375 - val_loss: 0.0834 - val_precision: 0.7742 - val_recall: 0.2105 - val_auc: 0.8384 - val_f1_score: 0.2519 - val_specificity_at_sensitivity: 0.9085 - val_mean_io_u: 0.4375
# Epoch 78/100
# 114/114 [==============================] - 36s 320ms/step - loss: 0.0834 - precision: 0.8069 - recall: 0.2068 - auc: 0.8207 - f1_score: 0.2649 - specificity_at_sensitivity: 0.9055 - mean_io_u: 0.4375 - val_loss: 0.0832 - val_precision: 0.7353 - val_recall: 0.2193 - val_auc: 0.8367 - val_f1_score: 0.2754 - val_specificity_at_sensitivity: 0.9135 - val_mean_io_u: 0.4375
# Epoch 79/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.0831 - precision: 0.8051 - recall: 0.2090 - auc: 0.8266 - f1_score: 0.2667 - specificity_at_sensitivity: 0.9098 - mean_io_u: 0.4375 - val_loss: 0.0837 - val_precision: 0.7273 - val_recall: 0.2105 - val_auc: 0.8358 - val_f1_score: 0.2519 - val_specificity_at_sensitivity: 0.9098 - val_mean_io_u: 0.4375
# Epoch 80/100
# 114/114 [==============================] - 35s 309ms/step - loss: 0.0838 - precision: 0.7727 - recall: 0.2244 - auc: 0.8228 - f1_score: 0.2818 - specificity_at_sensitivity: 0.9081 - mean_io_u: 0.4375 - val_loss: 0.0830 - val_precision: 0.7353 - val_recall: 0.2193 - val_auc: 0.8374 - val_f1_score: 0.2754 - val_specificity_at_sensitivity: 0.9148 - val_mean_io_u: 0.4375
# Epoch 81/100
# 114/114 [==============================] - 36s 318ms/step - loss: 0.0841 - precision: 0.7742 - recall: 0.2112 - auc: 0.8225 - f1_score: 0.2704 - specificity_at_sensitivity: 0.8980 - mean_io_u: 0.4375 - val_loss: 0.0825 - val_precision: 0.7879 - val_recall: 0.2281 - val_auc: 0.8397 - val_f1_score: 0.2774 - val_specificity_at_sensitivity: 0.9110 - val_mean_io_u: 0.4375
# Epoch 82/100
# 114/114 [==============================] - 35s 308ms/step - loss: 0.0838 - precision: 0.7842 - recall: 0.2079 - auc: 0.8213 - f1_score: 0.2647 - specificity_at_sensitivity: 0.9019 - mean_io_u: 0.4375 - val_loss: 0.0827 - val_precision: 0.7222 - val_recall: 0.2281 - val_auc: 0.8398 - val_f1_score: 0.2774 - val_specificity_at_sensitivity: 0.9173 - val_mean_io_u: 0.4375
# Epoch 83/100
# 114/114 [==============================] - 35s 308ms/step - loss: 0.0841 - precision: 0.7888 - recall: 0.2178 - auc: 0.8198 - f1_score: 0.2847 - specificity_at_sensitivity: 0.9022 - mean_io_u: 0.4375 - val_loss: 0.0825 - val_precision: 0.7143 - val_recall: 0.2193 - val_auc: 0.8401 - val_f1_score: 0.2774 - val_specificity_at_sensitivity: 0.9223 - val_mean_io_u: 0.4375
# Epoch 84/100
# 114/114 [==============================] - 35s 304ms/step - loss: 0.0824 - precision: 0.8063 - recall: 0.2244 - auc: 0.8303 - f1_score: 0.2894 - specificity_at_sensitivity: 0.8994 - mean_io_u: 0.4375 - val_loss: 0.0829 - val_precision: 0.6765 - val_recall: 0.2018 - val_auc: 0.8383 - val_f1_score: 0.2774 - val_specificity_at_sensitivity: 0.9135 - val_mean_io_u: 0.4375
# Epoch 85/100
# 114/114 [==============================] - 36s 313ms/step - loss: 0.0836 - precision: 0.7782 - recall: 0.2123 - auc: 0.8250 - f1_score: 0.2736 - specificity_at_sensitivity: 0.8996 - mean_io_u: 0.4375 - val_loss: 0.0831 - val_precision: 0.6970 - val_recall: 0.2018 - val_auc: 0.8380 - val_f1_score: 0.2774 - val_specificity_at_sensitivity: 0.9185 - val_mean_io_u: 0.4375
# Epoch 86/100
# 114/114 [==============================] - 36s 314ms/step - loss: 0.0830 - precision: 0.7715 - recall: 0.2266 - auc: 0.8279 - f1_score: 0.2976 - specificity_at_sensitivity: 0.8955 - mean_io_u: 0.4375 - val_loss: 0.0823 - val_precision: 0.7812 - val_recall: 0.2193 - val_auc: 0.8427 - val_f1_score: 0.2774 - val_specificity_at_sensitivity: 0.9148 - val_mean_io_u: 0.4375
# Epoch 87/100
# 114/114 [==============================] - 36s 318ms/step - loss: 0.0830 - precision: 0.7675 - recall: 0.2288 - auc: 0.8295 - f1_score: 0.2870 - specificity_at_sensitivity: 0.9066 - mean_io_u: 0.4375 - val_loss: 0.0822 - val_precision: 0.7027 - val_recall: 0.2281 - val_auc: 0.8403 - val_f1_score: 0.3000 - val_specificity_at_sensitivity: 0.9123 - val_mean_io_u: 0.4375
# Epoch 88/100
# 114/114 [==============================] - 36s 320ms/step - loss: 0.0840 - precision: 0.7659 - recall: 0.2123 - auc: 0.8217 - f1_score: 0.2948 - specificity_at_sensitivity: 0.9008 - mean_io_u: 0.4375 - val_loss: 0.0822 - val_precision: 0.7647 - val_recall: 0.2281 - val_auc: 0.8415 - val_f1_score: 0.2899 - val_specificity_at_sensitivity: 0.9185 - val_mean_io_u: 0.4375
# Epoch 89/100
# 114/114 [==============================] - 35s 309ms/step - loss: 0.0828 - precision: 0.7969 - recall: 0.2288 - auc: 0.8290 - f1_score: 0.2951 - specificity_at_sensitivity: 0.9112 - mean_io_u: 0.4375 - val_loss: 0.0832 - val_precision: 0.7027 - val_recall: 0.2281 - val_auc: 0.8342 - val_f1_score: 0.2958 - val_specificity_at_sensitivity: 0.9110 - val_mean_io_u: 0.4375
# Epoch 90/100
# 114/114 [==============================] - 35s 310ms/step - loss: 0.0816 - precision: 0.7860 - recall: 0.2222 - auc: 0.8352 - f1_score: 0.3047 - specificity_at_sensitivity: 0.9137 - mean_io_u: 0.4375 - val_loss: 0.0824 - val_precision: 0.7576 - val_recall: 0.2193 - val_auc: 0.8413 - val_f1_score: 0.2899 - val_specificity_at_sensitivity: 0.9223 - val_mean_io_u: 0.4375
# Epoch 91/100
# 114/114 [==============================] - 36s 317ms/step - loss: 0.0830 - precision: 0.7707 - recall: 0.2255 - auc: 0.8297 - f1_score: 0.2865 - specificity_at_sensitivity: 0.9071 - mean_io_u: 0.4375 - val_loss: 0.0819 - val_precision: 0.6757 - val_recall: 0.2193 - val_auc: 0.8401 - val_f1_score: 0.3022 - val_specificity_at_sensitivity: 0.9198 - val_mean_io_u: 0.4375
# Epoch 92/100
# 114/114 [==============================] - 35s 309ms/step - loss: 0.0824 - precision: 0.7930 - recall: 0.2233 - auc: 0.8319 - f1_score: 0.2922 - specificity_at_sensitivity: 0.9051 - mean_io_u: 0.4375 - val_loss: 0.0819 - val_precision: 0.7353 - val_recall: 0.2193 - val_auc: 0.8401 - val_f1_score: 0.3143 - val_specificity_at_sensitivity: 0.9211 - val_mean_io_u: 0.4375
# Epoch 93/100
# 114/114 [==============================] - 35s 307ms/step - loss: 0.0814 - precision: 0.8182 - recall: 0.2376 - auc: 0.8342 - f1_score: 0.3128 - specificity_at_sensitivity: 0.9128 - mean_io_u: 0.4375 - val_loss: 0.0815 - val_precision: 0.7429 - val_recall: 0.2281 - val_auc: 0.8428 - val_f1_score: 0.3143 - val_specificity_at_sensitivity: 0.9211 - val_mean_io_u: 0.4375
# Epoch 94/100
# 114/114 [==============================] - 36s 314ms/step - loss: 0.0817 - precision: 0.7985 - recall: 0.2354 - auc: 0.8378 - f1_score: 0.2922 - specificity_at_sensitivity: 0.9026 - mean_io_u: 0.4375 - val_loss: 0.0815 - val_precision: 0.7647 - val_recall: 0.2281 - val_auc: 0.8441 - val_f1_score: 0.3022 - val_specificity_at_sensitivity: 0.9223 - val_mean_io_u: 0.4375
# Epoch 95/100
# 114/114 [==============================] - 36s 317ms/step - loss: 0.0825 - precision: 0.7727 - recall: 0.2244 - auc: 0.8306 - f1_score: 0.3017 - specificity_at_sensitivity: 0.9103 - mean_io_u: 0.4375 - val_loss: 0.0811 - val_precision: 0.7647 - val_recall: 0.2281 - val_auc: 0.8450 - val_f1_score: 0.3121 - val_specificity_at_sensitivity: 0.9223 - val_mean_io_u: 0.4375
# Epoch 96/100
# 114/114 [==============================] - 36s 320ms/step - loss: 0.0822 - precision: 0.7899 - recall: 0.2233 - auc: 0.8313 - f1_score: 0.3095 - specificity_at_sensitivity: 0.9137 - mean_io_u: 0.4375 - val_loss: 0.0809 - val_precision: 0.7714 - val_recall: 0.2368 - val_auc: 0.8451 - val_f1_score: 0.3143 - val_specificity_at_sensitivity: 0.9236 - val_mean_io_u: 0.4375
# Epoch 97/100
# 114/114 [==============================] - 35s 311ms/step - loss: 0.0805 - precision: 0.8315 - recall: 0.2442 - auc: 0.8383 - f1_score: 0.3023 - specificity_at_sensitivity: 0.9173 - mean_io_u: 0.4375 - val_loss: 0.0808 - val_precision: 0.7353 - val_recall: 0.2193 - val_auc: 0.8456 - val_f1_score: 0.3043 - val_specificity_at_sensitivity: 0.9223 - val_mean_io_u: 0.4375
# Epoch 98/100
# 114/114 [==============================] - 35s 310ms/step - loss: 0.0815 - precision: 0.8000 - recall: 0.2288 - auc: 0.8394 - f1_score: 0.2962 - specificity_at_sensitivity: 0.9087 - mean_io_u: 0.4375 - val_loss: 0.0812 - val_precision: 0.6757 - val_recall: 0.2193 - val_auc: 0.8434 - val_f1_score: 0.3000 - val_specificity_at_sensitivity: 0.9286 - val_mean_io_u: 0.4375
# Epoch 99/100
# 114/114 [==============================] - 36s 319ms/step - loss: 0.0811 - precision: 0.7889 - recall: 0.2343 - auc: 0.8402 - f1_score: 0.2982 - specificity_at_sensitivity: 0.9158 - mean_io_u: 0.4375 - val_loss: 0.0813 - val_precision: 0.7143 - val_recall: 0.2193 - val_auc: 0.8437 - val_f1_score: 0.3000 - val_specificity_at_sensitivity: 0.9273 - val_mean_io_u: 0.4375
# Epoch 100/100
# 114/114 [==============================] - 35s 310ms/step - loss: 0.0817 - precision: 0.7545 - recall: 0.2299 - auc: 0.8398 - f1_score: 0.3052 - specificity_at_sensitivity: 0.9161 - mean_io_u: 0.4375 - val_loss: 0.0808 - val_precision: 0.7429 - val_recall: 0.2281 - val_auc: 0.8468 - val_f1_score: 0.3022 - val_specificity_at_sensitivity: 0.9286 - val_mean_io_u: 0.4375
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## **모델 테스트**

# %%
temp_y = enc.fit_transform(y_test).toarray()
y_test = temp_y

test_metrics = model.evaluate(x_test, y_test)
print("Test Metrics:", test_metrics)
print(hist.history.keys())
# Out:
# 4/4 [==============================] - 1s 208ms/step - loss: 0.0923 - precision: 0.6207 - recall: 0.1579 - auc: 0.7944 - f1_score: 0.2319 - specificity_at_sensitivity: 0.8747 - mean_io_u: 0.4375
# Test Metrics: [0.09233775734901428, 0.6206896305084229, 0.15789473056793213, 0.794414758682251, 0.23188404738903046, 0.8746867179870605, 0.4375]
# dict_keys(['loss', 'precision', 'recall', 'auc', 'f1_score', 'specificity_at_sensitivity', 'mean_io_u', 'val_loss', 'val_precision', 'val_recall', 'val_auc', 'val_f1_score', 'val_specificity_at_sensitivity', 'val_mean_io_u'])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'],'y',label='train loss')
loss_ax.plot(hist.history['val_loss'],'r',label='val loss')
acc_ax.plot(hist.history['auc'],'b',label='train acc')
acc_ax.plot(hist.history['val_auc'],'g',label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')
plt.show()

# %%
print('##### Test Result #####')
print('loss : ',str(test_metrics[0]))
print('Accuracy : ',str(test_metrics[1]))
# Out:
# ##### Test Result #####
# loss :  0.09233775734901428
# Accuracy :  0.6206896305084229
