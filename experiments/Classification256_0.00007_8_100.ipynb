# %% [markdown]
# ## **드라이브 마운트**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#%cd /content/drive/MyDrive/Classification

#%cd /content/drive/MyDrive/Classification_balanced_128

# %cd /content/drive/MyDrive/Classification_balanced_256
# Out:
# /content/drive/MyDrive/Classification_balanced_256

# %% [markdown]
# ## **필요 라이브러리 설치**

# %%
# !pip install tensorflow-addons==0.22.0
# Out:
# Collecting tensorflow-addons==0.22.0
#   Downloading tensorflow_addons-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.3/612.3 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons==0.22.0) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons==0.22.0)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.22.0 typeguard-2.13.3

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import os
import cv2
import numpy as np

from model_layer import * #모듈화한 모델 import
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder

import keras.backend as K
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# ## **Train, Validation, Test 데이터셋**

# %%
os.makedirs('checkpoints', exist_ok=True)

test1 = 0
test2 = 1
test3 = 2
test4 = 3
test5 = 4
level1=10
level2=20

file_name=[]

train = 0
val = 1
test = 2

def make_test_data(test1,level1, num):
  X=[]
  y=[]

  for f_label, folder_name in enumerate(('ACTINIC_KERATOSIS', 'BASAL_CELL_CARCINOMA', 'DERMATOFIBROMA', 'MELANOMA', 'NEVUS', 'PIGMENTED_BENIGN_KERATOSIS', 'SQUAMOUS_CELL_CARCIMONA','VASCULAR_LESION')):
    folder_path = os.path.join("./dataset_"+str(num)+"/", folder_name)
    print(folder_path)

    for fname in os.listdir(folder_path):
        fpath = os.path.join(folder_path, fname)
        if num == test:
          file_name.append(fpath)

        img = cv2.imread(fpath, cv2.IMREAD_COLOR)
        img = cv2.resize(img, image_shape[1:])

        X.append(img)
        y.append(f_label)

  X = np.array(X)
  y = np.array(y).reshape(-1, 1)

  X = (X / 255.)
  X = X.transpose(0, 3, 1, 2)
  X = X.astype(np.float32)
  y = y.astype(np.float32)

  x_train = X
  y_train = y
  return x_train, y_train

#image_shape = (3, 128, 128)
image_shape = (3, 256, 256)

x_train, y_train= make_test_data(test1,level1, train)
x_val, y_val= make_test_data(test1,level1, val)
x_test, y_test= make_test_data(test1,level1, test)

enc = OneHotEncoder(handle_unknown='ignore')
temp_y = enc.fit_transform(y_train).toarray()
y_train = temp_y

temp_y = enc.fit_transform(y_val).toarray()
y_val = temp_y
# Out:
# ./dataset_0/ACTINIC_KERATOSIS
# ./dataset_0/BASAL_CELL_CARCINOMA
# ./dataset_0/DERMATOFIBROMA
# ./dataset_0/MELANOMA
# ./dataset_0/NEVUS
# ./dataset_0/PIGMENTED_BENIGN_KERATOSIS
# ./dataset_0/SQUAMOUS_CELL_CARCIMONA
# ./dataset_0/VASCULAR_LESION
# ./dataset_1/ACTINIC_KERATOSIS
# ./dataset_1/BASAL_CELL_CARCINOMA
# ./dataset_1/DERMATOFIBROMA
# ./dataset_1/MELANOMA
# ./dataset_1/NEVUS
# ./dataset_1/PIGMENTED_BENIGN_KERATOSIS
# ./dataset_1/SQUAMOUS_CELL_CARCIMONA
# ./dataset_1/VASCULAR_LESION
# ./dataset_2/ACTINIC_KERATOSIS
# ./dataset_2/BASAL_CELL_CARCINOMA
# ./dataset_2/DERMATOFIBROMA
# ./dataset_2/MELANOMA
# ./dataset_2/NEVUS
# ./dataset_2/PIGMENTED_BENIGN_KERATOSIS
# ./dataset_2/SQUAMOUS_CELL_CARCIMONA
# ./dataset_2/VASCULAR_LESION

# %% [markdown]
# ## **모델 선언**

# %%
#make model
model = make_model(image_shape, num_classes=8)

epochs = 100
ckpoint= tf.keras.callbacks.ModelCheckpoint(filepath='./model_save/',monitor='val_f1_score',save_best_only=True, save_weights_only=True)
earlystopping= tf.keras.callbacks.EarlyStopping(monitor='val_f1_score', patience=10,mode='max')

precision = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()
auc = tf.keras.metrics.AUC()
spec=tf.keras.metrics.SpecificityAtSensitivity(0.5)
iou=tf.keras.metrics.MeanIoU(num_classes=8)
f1_score = tfa.metrics.F1Score(num_classes=8, threshold=0.6,average='micro')

learningrate=0.00007
batch = 8
opt1=tf.keras.optimizers.Adamax(learning_rate=learningrate)
opt3=tf.keras.optimizers.Adam(learning_rate=learningrate)
opt1=tf.keras.mixed_precision.LossScaleOptimizer(opt1)

# %% [markdown]
# ## **모델 학습**

# %%
losses  = 'mse'
model.compile(
        optimizer = opt1,
        loss = losses,
        metrics = [precision, recall, auc,f1_score,spec,iou]
)

hist = model.fit(x_train, y_train,epochs=epochs,batch_size=batch,validation_data = (x_val, y_val),
        callbacks = [ckpoint]
)

model.save("./model_save/classification256_model_"+str(test1)+"0.00007_8_100.h5", include_optimizer=True)
# Out:
# Epoch 1/100
# 114/114 [==============================] - 50s 360ms/step - loss: 0.1058 - precision: 0.7500 - recall: 0.0033 - auc: 0.6724 - f1_score: 0.0022 - specificity_at_sensitivity: 0.5871 - mean_io_u: 0.4375 - val_loss: 0.1094 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_f1_score: 0.0000e+00 - val_specificity_at_sensitivity: 0.0000e+00 - val_mean_io_u: 0.4375
# Epoch 2/100
# 114/114 [==============================] - 45s 398ms/step - loss: 0.0975 - precision: 0.7126 - recall: 0.0682 - auc: 0.7455 - f1_score: 0.0839 - specificity_at_sensitivity: 0.8155 - mean_io_u: 0.4375 - val_loss: 0.1094 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4975 - val_f1_score: 0.0000e+00 - val_specificity_at_sensitivity: 0.0000e+00 - val_mean_io_u: 0.4375
# Epoch 3/100
# 114/114 [==============================] - 40s 346ms/step - loss: 0.0953 - precision: 0.6981 - recall: 0.0814 - auc: 0.7628 - f1_score: 0.1144 - specificity_at_sensitivity: 0.8427 - mean_io_u: 0.4375 - val_loss: 0.1094 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4994 - val_f1_score: 0.0000e+00 - val_specificity_at_sensitivity: 0.0000e+00 - val_mean_io_u: 0.4375
# Epoch 4/100
# 114/114 [==============================] - 39s 344ms/step - loss: 0.0936 - precision: 0.7519 - recall: 0.1067 - auc: 0.7693 - f1_score: 0.1221 - specificity_at_sensitivity: 0.8362 - mean_io_u: 0.4375 - val_loss: 0.1095 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4832 - val_f1_score: 0.0000e+00 - val_specificity_at_sensitivity: 0.3747 - val_mean_io_u: 0.4375
# Epoch 5/100
# 114/114 [==============================] - 39s 342ms/step - loss: 0.0900 - precision: 0.8242 - recall: 0.1496 - auc: 0.7891 - f1_score: 0.1682 - specificity_at_sensitivity: 0.8633 - mean_io_u: 0.4375 - val_loss: 0.1097 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5343 - val_f1_score: 0.0000e+00 - val_specificity_at_sensitivity: 0.5263 - val_mean_io_u: 0.4375
# Epoch 6/100
# 114/114 [==============================] - 41s 356ms/step - loss: 0.0878 - precision: 0.7535 - recall: 0.1782 - auc: 0.8007 - f1_score: 0.2275 - specificity_at_sensitivity: 0.8810 - mean_io_u: 0.4375 - val_loss: 0.1086 - val_precision: 1.0000 - val_recall: 0.0088 - val_auc: 0.5920 - val_f1_score: 0.0000e+00 - val_specificity_at_sensitivity: 0.6266 - val_mean_io_u: 0.4375
# Epoch 7/100
# 114/114 [==============================] - 41s 359ms/step - loss: 0.0861 - precision: 0.7834 - recall: 0.1870 - auc: 0.8129 - f1_score: 0.2453 - specificity_at_sensitivity: 0.8952 - mean_io_u: 0.4375 - val_loss: 0.1026 - val_precision: 0.6000 - val_recall: 0.0526 - val_auc: 0.6843 - val_f1_score: 0.0336 - val_specificity_at_sensitivity: 0.7043 - val_mean_io_u: 0.4375
# Epoch 8/100
# 114/114 [==============================] - 41s 362ms/step - loss: 0.0856 - precision: 0.7500 - recall: 0.1980 - auc: 0.8150 - f1_score: 0.2610 - specificity_at_sensitivity: 0.8947 - mean_io_u: 0.4375 - val_loss: 0.0896 - val_precision: 0.7692 - val_recall: 0.0877 - val_auc: 0.8157 - val_f1_score: 0.1440 - val_specificity_at_sensitivity: 0.8659 - val_mean_io_u: 0.4375
# Epoch 9/100
# 114/114 [==============================] - 39s 340ms/step - loss: 0.0838 - precision: 0.7649 - recall: 0.2112 - auc: 0.8247 - f1_score: 0.2807 - specificity_at_sensitivity: 0.9077 - mean_io_u: 0.4375 - val_loss: 0.0814 - val_precision: 0.8000 - val_recall: 0.2456 - val_auc: 0.8400 - val_f1_score: 0.3043 - val_specificity_at_sensitivity: 0.9123 - val_mean_io_u: 0.4375
# Epoch 10/100
# 114/114 [==============================] - 39s 346ms/step - loss: 0.0826 - precision: 0.8063 - recall: 0.2244 - auc: 0.8287 - f1_score: 0.3032 - specificity_at_sensitivity: 0.9005 - mean_io_u: 0.4375 - val_loss: 0.0864 - val_precision: 0.6842 - val_recall: 0.2281 - val_auc: 0.8184 - val_f1_score: 0.2937 - val_specificity_at_sensitivity: 0.8872 - val_mean_io_u: 0.4375
# Epoch 11/100
# 114/114 [==============================] - 41s 360ms/step - loss: 0.0825 - precision: 0.7846 - recall: 0.2244 - auc: 0.8320 - f1_score: 0.2912 - specificity_at_sensitivity: 0.9114 - mean_io_u: 0.4375 - val_loss: 0.0818 - val_precision: 0.7949 - val_recall: 0.2719 - val_auc: 0.8373 - val_f1_score: 0.3143 - val_specificity_at_sensitivity: 0.9110 - val_mean_io_u: 0.4375
# Epoch 12/100
# 114/114 [==============================] - 39s 340ms/step - loss: 0.0805 - precision: 0.8081 - recall: 0.2409 - auc: 0.8384 - f1_score: 0.3163 - specificity_at_sensitivity: 0.9203 - mean_io_u: 0.4375 - val_loss: 0.0835 - val_precision: 0.7179 - val_recall: 0.2456 - val_auc: 0.8265 - val_f1_score: 0.3056 - val_specificity_at_sensitivity: 0.9185 - val_mean_io_u: 0.4375
# Epoch 13/100
# 114/114 [==============================] - 39s 340ms/step - loss: 0.0811 - precision: 0.7790 - recall: 0.2288 - auc: 0.8427 - f1_score: 0.3002 - specificity_at_sensitivity: 0.9172 - mean_io_u: 0.4375 - val_loss: 0.0885 - val_precision: 0.5897 - val_recall: 0.2018 - val_auc: 0.8101 - val_f1_score: 0.2979 - val_specificity_at_sensitivity: 0.8960 - val_mean_io_u: 0.4375
# Epoch 14/100
# 114/114 [==============================] - 39s 339ms/step - loss: 0.0807 - precision: 0.7651 - recall: 0.2365 - auc: 0.8448 - f1_score: 0.3242 - specificity_at_sensitivity: 0.9191 - mean_io_u: 0.4375 - val_loss: 0.0809 - val_precision: 0.7083 - val_recall: 0.2982 - val_auc: 0.8416 - val_f1_score: 0.3448 - val_specificity_at_sensitivity: 0.9361 - val_mean_io_u: 0.4375
# Epoch 15/100
# 114/114 [==============================] - 40s 352ms/step - loss: 0.0787 - precision: 0.7986 - recall: 0.2486 - auc: 0.8504 - f1_score: 0.3339 - specificity_at_sensitivity: 0.9283 - mean_io_u: 0.4375 - val_loss: 0.0795 - val_precision: 0.7895 - val_recall: 0.2632 - val_auc: 0.8413 - val_f1_score: 0.3309 - val_specificity_at_sensitivity: 0.9323 - val_mean_io_u: 0.4375
# Epoch 16/100
# 114/114 [==============================] - 40s 346ms/step - loss: 0.0782 - precision: 0.8020 - recall: 0.2585 - auc: 0.8540 - f1_score: 0.3319 - specificity_at_sensitivity: 0.9349 - mean_io_u: 0.4375 - val_loss: 0.0796 - val_precision: 0.7674 - val_recall: 0.2895 - val_auc: 0.8451 - val_f1_score: 0.3611 - val_specificity_at_sensitivity: 0.9286 - val_mean_io_u: 0.4375
# Epoch 17/100
# 114/114 [==============================] - 39s 339ms/step - loss: 0.0787 - precision: 0.7842 - recall: 0.2519 - auc: 0.8540 - f1_score: 0.3360 - specificity_at_sensitivity: 0.9255 - mean_io_u: 0.4375 - val_loss: 0.0803 - val_precision: 0.7949 - val_recall: 0.2719 - val_auc: 0.8509 - val_f1_score: 0.3404 - val_specificity_at_sensitivity: 0.9248 - val_mean_io_u: 0.4375
# Epoch 18/100
# 114/114 [==============================] - 39s 341ms/step - loss: 0.0764 - precision: 0.8241 - recall: 0.2629 - auc: 0.8627 - f1_score: 0.3446 - specificity_at_sensitivity: 0.9364 - mean_io_u: 0.4375 - val_loss: 0.0791 - val_precision: 0.7381 - val_recall: 0.2719 - val_auc: 0.8500 - val_f1_score: 0.3867 - val_specificity_at_sensitivity: 0.9211 - val_mean_io_u: 0.4375
# Epoch 19/100
# 114/114 [==============================] - 41s 358ms/step - loss: 0.0754 - precision: 0.8185 - recall: 0.2926 - auc: 0.8642 - f1_score: 0.3608 - specificity_at_sensitivity: 0.9452 - mean_io_u: 0.4375 - val_loss: 0.0814 - val_precision: 0.7273 - val_recall: 0.2807 - val_auc: 0.8489 - val_f1_score: 0.3841 - val_specificity_at_sensitivity: 0.9110 - val_mean_io_u: 0.4375
# Epoch 20/100
# 114/114 [==============================] - 41s 361ms/step - loss: 0.0749 - precision: 0.7994 - recall: 0.2937 - auc: 0.8736 - f1_score: 0.3724 - specificity_at_sensitivity: 0.9458 - mean_io_u: 0.4375 - val_loss: 0.0817 - val_precision: 0.6739 - val_recall: 0.2719 - val_auc: 0.8422 - val_f1_score: 0.3537 - val_specificity_at_sensitivity: 0.9085 - val_mean_io_u: 0.4375
# Epoch 21/100
# 114/114 [==============================] - 39s 345ms/step - loss: 0.0751 - precision: 0.8107 - recall: 0.3014 - auc: 0.8687 - f1_score: 0.3647 - specificity_at_sensitivity: 0.9470 - mean_io_u: 0.4375 - val_loss: 0.0875 - val_precision: 0.6190 - val_recall: 0.3421 - val_auc: 0.8236 - val_f1_score: 0.3590 - val_specificity_at_sensitivity: 0.9073 - val_mean_io_u: 0.4375
# Epoch 22/100
# 114/114 [==============================] - 39s 340ms/step - loss: 0.0737 - precision: 0.7953 - recall: 0.2948 - auc: 0.8758 - f1_score: 0.3905 - specificity_at_sensitivity: 0.9527 - mean_io_u: 0.4375 - val_loss: 0.0806 - val_precision: 0.7115 - val_recall: 0.3246 - val_auc: 0.8387 - val_f1_score: 0.3816 - val_specificity_at_sensitivity: 0.9336 - val_mean_io_u: 0.4375
# Epoch 23/100
# 114/114 [==============================] - 39s 340ms/step - loss: 0.0727 - precision: 0.8348 - recall: 0.3058 - auc: 0.8795 - f1_score: 0.3690 - specificity_at_sensitivity: 0.9525 - mean_io_u: 0.4375 - val_loss: 0.0752 - val_precision: 0.7586 - val_recall: 0.3860 - val_auc: 0.8507 - val_f1_score: 0.4528 - val_specificity_at_sensitivity: 0.9511 - val_mean_io_u: 0.4375
# Epoch 24/100
# 114/114 [==============================] - 40s 351ms/step - loss: 0.0723 - precision: 0.8044 - recall: 0.3212 - auc: 0.8816 - f1_score: 0.4087 - specificity_at_sensitivity: 0.9518 - mean_io_u: 0.4375 - val_loss: 0.0879 - val_precision: 0.5769 - val_recall: 0.2632 - val_auc: 0.8349 - val_f1_score: 0.3444 - val_specificity_at_sensitivity: 0.8684 - val_mean_io_u: 0.4375
# Epoch 25/100
# 114/114 [==============================] - 39s 345ms/step - loss: 0.0720 - precision: 0.8314 - recall: 0.3146 - auc: 0.8848 - f1_score: 0.3976 - specificity_at_sensitivity: 0.9530 - mean_io_u: 0.4375 - val_loss: 0.0843 - val_precision: 0.6875 - val_recall: 0.2895 - val_auc: 0.8340 - val_f1_score: 0.3649 - val_specificity_at_sensitivity: 0.9085 - val_mean_io_u: 0.4375
# Epoch 26/100
# 114/114 [==============================] - 38s 337ms/step - loss: 0.0718 - precision: 0.7961 - recall: 0.3179 - auc: 0.8866 - f1_score: 0.3980 - specificity_at_sensitivity: 0.9538 - mean_io_u: 0.4375 - val_loss: 0.0897 - val_precision: 0.5965 - val_recall: 0.2982 - val_auc: 0.8116 - val_f1_score: 0.3490 - val_specificity_at_sensitivity: 0.8697 - val_mean_io_u: 0.4375
# Epoch 27/100
# 114/114 [==============================] - 38s 336ms/step - loss: 0.0705 - precision: 0.8315 - recall: 0.3366 - auc: 0.8858 - f1_score: 0.4098 - specificity_at_sensitivity: 0.9612 - mean_io_u: 0.4375 - val_loss: 0.0806 - val_precision: 0.6727 - val_recall: 0.3246 - val_auc: 0.8435 - val_f1_score: 0.4204 - val_specificity_at_sensitivity: 0.9185 - val_mean_io_u: 0.4375
# Epoch 28/100
# 114/114 [==============================] - 39s 341ms/step - loss: 0.0708 - precision: 0.8082 - recall: 0.3476 - auc: 0.8849 - f1_score: 0.4137 - specificity_at_sensitivity: 0.9588 - mean_io_u: 0.4375 - val_loss: 0.0861 - val_precision: 0.6061 - val_recall: 0.3509 - val_auc: 0.8377 - val_f1_score: 0.4000 - val_specificity_at_sensitivity: 0.8972 - val_mean_io_u: 0.4375
# Epoch 29/100
# 114/114 [==============================] - 41s 356ms/step - loss: 0.0696 - precision: 0.8140 - recall: 0.3322 - auc: 0.8924 - f1_score: 0.4174 - specificity_at_sensitivity: 0.9635 - mean_io_u: 0.4375 - val_loss: 0.0801 - val_precision: 0.6719 - val_recall: 0.3772 - val_auc: 0.8390 - val_f1_score: 0.4403 - val_specificity_at_sensitivity: 0.9436 - val_mean_io_u: 0.4375
# Epoch 30/100
# 114/114 [==============================] - 43s 372ms/step - loss: 0.0686 - precision: 0.8098 - recall: 0.3465 - auc: 0.8972 - f1_score: 0.4257 - specificity_at_sensitivity: 0.9640 - mean_io_u: 0.4375 - val_loss: 0.0800 - val_precision: 0.6885 - val_recall: 0.3684 - val_auc: 0.8339 - val_f1_score: 0.4699 - val_specificity_at_sensitivity: 0.9436 - val_mean_io_u: 0.4375
# Epoch 31/100
# 114/114 [==============================] - 38s 334ms/step - loss: 0.0690 - precision: 0.8024 - recall: 0.3663 - auc: 0.8951 - f1_score: 0.4328 - specificity_at_sensitivity: 0.9640 - mean_io_u: 0.4375 - val_loss: 0.0813 - val_precision: 0.6667 - val_recall: 0.3684 - val_auc: 0.8458 - val_f1_score: 0.4177 - val_specificity_at_sensitivity: 0.9261 - val_mean_io_u: 0.4375
# Epoch 32/100
# 114/114 [==============================] - 38s 333ms/step - loss: 0.0674 - precision: 0.8077 - recall: 0.3696 - auc: 0.9008 - f1_score: 0.4437 - specificity_at_sensitivity: 0.9646 - mean_io_u: 0.4375 - val_loss: 0.0821 - val_precision: 0.6133 - val_recall: 0.4035 - val_auc: 0.8390 - val_f1_score: 0.4634 - val_specificity_at_sensitivity: 0.9198 - val_mean_io_u: 0.4375
# Epoch 33/100
# 114/114 [==============================] - 38s 338ms/step - loss: 0.0676 - precision: 0.7780 - recall: 0.3663 - auc: 0.8997 - f1_score: 0.4437 - specificity_at_sensitivity: 0.9665 - mean_io_u: 0.4375 - val_loss: 0.0789 - val_precision: 0.7241 - val_recall: 0.3684 - val_auc: 0.8477 - val_f1_score: 0.4304 - val_specificity_at_sensitivity: 0.9248 - val_mean_io_u: 0.4375
# Epoch 34/100
# 114/114 [==============================] - 40s 348ms/step - loss: 0.0675 - precision: 0.8212 - recall: 0.3839 - auc: 0.8951 - f1_score: 0.4406 - specificity_at_sensitivity: 0.9705 - mean_io_u: 0.4375 - val_loss: 0.0773 - val_precision: 0.6818 - val_recall: 0.3947 - val_auc: 0.8420 - val_f1_score: 0.4684 - val_specificity_at_sensitivity: 0.9449 - val_mean_io_u: 0.4375
# Epoch 35/100
# 114/114 [==============================] - 41s 355ms/step - loss: 0.0658 - precision: 0.8092 - recall: 0.3872 - auc: 0.9045 - f1_score: 0.4609 - specificity_at_sensitivity: 0.9717 - mean_io_u: 0.4375 - val_loss: 0.0832 - val_precision: 0.5921 - val_recall: 0.3947 - val_auc: 0.8419 - val_f1_score: 0.4074 - val_specificity_at_sensitivity: 0.9173 - val_mean_io_u: 0.4375
# Epoch 36/100
# 114/114 [==============================] - 38s 334ms/step - loss: 0.0655 - precision: 0.8190 - recall: 0.3883 - auc: 0.9060 - f1_score: 0.4589 - specificity_at_sensitivity: 0.9714 - mean_io_u: 0.4375 - val_loss: 0.0945 - val_precision: 0.4783 - val_recall: 0.2895 - val_auc: 0.8006 - val_f1_score: 0.3273 - val_specificity_at_sensitivity: 0.8985 - val_mean_io_u: 0.4375
# Epoch 37/100
# 114/114 [==============================] - 38s 334ms/step - loss: 0.0643 - precision: 0.8064 - recall: 0.4169 - auc: 0.9073 - f1_score: 0.4885 - specificity_at_sensitivity: 0.9745 - mean_io_u: 0.4375 - val_loss: 0.0856 - val_precision: 0.5556 - val_recall: 0.3509 - val_auc: 0.8363 - val_f1_score: 0.4235 - val_specificity_at_sensitivity: 0.9211 - val_mean_io_u: 0.4375
# Epoch 38/100
# 114/114 [==============================] - 38s 337ms/step - loss: 0.0632 - precision: 0.8308 - recall: 0.4268 - auc: 0.9125 - f1_score: 0.4844 - specificity_at_sensitivity: 0.9778 - mean_io_u: 0.4375 - val_loss: 0.0916 - val_precision: 0.5692 - val_recall: 0.3246 - val_auc: 0.8078 - val_f1_score: 0.3832 - val_specificity_at_sensitivity: 0.8822 - val_mean_io_u: 0.4375
# Epoch 39/100
# 114/114 [==============================] - 40s 350ms/step - loss: 0.0629 - precision: 0.8160 - recall: 0.4147 - auc: 0.9126 - f1_score: 0.4912 - specificity_at_sensitivity: 0.9761 - mean_io_u: 0.4375 - val_loss: 0.0790 - val_precision: 0.6479 - val_recall: 0.4035 - val_auc: 0.8455 - val_f1_score: 0.4767 - val_specificity_at_sensitivity: 0.9499 - val_mean_io_u: 0.4375
# Epoch 40/100
# 114/114 [==============================] - 39s 344ms/step - loss: 0.0631 - precision: 0.8174 - recall: 0.4235 - auc: 0.9118 - f1_score: 0.5119 - specificity_at_sensitivity: 0.9749 - mean_io_u: 0.4375 - val_loss: 0.0894 - val_precision: 0.5238 - val_recall: 0.3860 - val_auc: 0.8201 - val_f1_score: 0.4246 - val_specificity_at_sensitivity: 0.9236 - val_mean_io_u: 0.4375
# Epoch 41/100
# 114/114 [==============================] - 44s 389ms/step - loss: 0.0600 - precision: 0.8471 - recall: 0.4510 - auc: 0.9200 - f1_score: 0.5233 - specificity_at_sensitivity: 0.9826 - mean_io_u: 0.4375 - val_loss: 0.0896 - val_precision: 0.5758 - val_recall: 0.3333 - val_auc: 0.8047 - val_f1_score: 0.3882 - val_specificity_at_sensitivity: 0.9135 - val_mean_io_u: 0.4375
# Epoch 42/100
# 114/114 [==============================] - 40s 350ms/step - loss: 0.0614 - precision: 0.8273 - recall: 0.4532 - auc: 0.9182 - f1_score: 0.5055 - specificity_at_sensitivity: 0.9800 - mean_io_u: 0.4375 - val_loss: 0.0909 - val_precision: 0.5507 - val_recall: 0.3333 - val_auc: 0.8267 - val_f1_score: 0.3952 - val_specificity_at_sensitivity: 0.8947 - val_mean_io_u: 0.4375
# Epoch 43/100
# 114/114 [==============================] - 40s 354ms/step - loss: 0.0609 - precision: 0.8198 - recall: 0.4455 - auc: 0.9182 - f1_score: 0.5148 - specificity_at_sensitivity: 0.9804 - mean_io_u: 0.4375 - val_loss: 0.0868 - val_precision: 0.5696 - val_recall: 0.3947 - val_auc: 0.8159 - val_f1_score: 0.4598 - val_specificity_at_sensitivity: 0.9110 - val_mean_io_u: 0.4375
# Epoch 44/100
# 114/114 [==============================] - 38s 335ms/step - loss: 0.0600 - precision: 0.8330 - recall: 0.4664 - auc: 0.9198 - f1_score: 0.5329 - specificity_at_sensitivity: 0.9822 - mean_io_u: 0.4375 - val_loss: 0.1047 - val_precision: 0.4490 - val_recall: 0.3860 - val_auc: 0.7661 - val_f1_score: 0.3936 - val_specificity_at_sensitivity: 0.8634 - val_mean_io_u: 0.4375
# Epoch 45/100
# 114/114 [==============================] - 38s 337ms/step - loss: 0.0604 - precision: 0.8303 - recall: 0.4576 - auc: 0.9201 - f1_score: 0.5321 - specificity_at_sensitivity: 0.9805 - mean_io_u: 0.4375 - val_loss: 0.0839 - val_precision: 0.6081 - val_recall: 0.3947 - val_auc: 0.8245 - val_f1_score: 0.4746 - val_specificity_at_sensitivity: 0.9311 - val_mean_io_u: 0.4375
# Epoch 46/100
# 114/114 [==============================] - 38s 334ms/step - loss: 0.0589 - precision: 0.8413 - recall: 0.4840 - auc: 0.9231 - f1_score: 0.5517 - specificity_at_sensitivity: 0.9835 - mean_io_u: 0.4375 - val_loss: 0.0925 - val_precision: 0.5714 - val_recall: 0.4211 - val_auc: 0.7951 - val_f1_score: 0.4481 - val_specificity_at_sensitivity: 0.9123 - val_mean_io_u: 0.4375
# Epoch 47/100
# 114/114 [==============================] - 40s 355ms/step - loss: 0.0588 - precision: 0.8455 - recall: 0.4697 - auc: 0.9239 - f1_score: 0.5362 - specificity_at_sensitivity: 0.9826 - mean_io_u: 0.4375 - val_loss: 0.0878 - val_precision: 0.5070 - val_recall: 0.3158 - val_auc: 0.8322 - val_f1_score: 0.4146 - val_specificity_at_sensitivity: 0.9085 - val_mean_io_u: 0.4375
# Epoch 48/100
# 114/114 [==============================] - 39s 341ms/step - loss: 0.0600 - precision: 0.8158 - recall: 0.4433 - auc: 0.9208 - f1_score: 0.5244 - specificity_at_sensitivity: 0.9788 - mean_io_u: 0.4375 - val_loss: 0.0883 - val_precision: 0.5732 - val_recall: 0.4123 - val_auc: 0.8211 - val_f1_score: 0.4773 - val_specificity_at_sensitivity: 0.9148 - val_mean_io_u: 0.4375
# Epoch 49/100
# 114/114 [==============================] - 38s 336ms/step - loss: 0.0571 - precision: 0.8470 - recall: 0.4873 - auc: 0.9302 - f1_score: 0.5404 - specificity_at_sensitivity: 0.9854 - mean_io_u: 0.4375 - val_loss: 0.0899 - val_precision: 0.5342 - val_recall: 0.3421 - val_auc: 0.8308 - val_f1_score: 0.3952 - val_specificity_at_sensitivity: 0.8922 - val_mean_io_u: 0.4375
# Epoch 50/100
# 114/114 [==============================] - 38s 337ms/step - loss: 0.0571 - precision: 0.8355 - recall: 0.4917 - auc: 0.9289 - f1_score: 0.5570 - specificity_at_sensitivity: 0.9846 - mean_io_u: 0.4375 - val_loss: 0.1010 - val_precision: 0.4375 - val_recall: 0.3070 - val_auc: 0.8211 - val_f1_score: 0.3605 - val_specificity_at_sensitivity: 0.8609 - val_mean_io_u: 0.4375
# Epoch 51/100
# 114/114 [==============================] - 38s 337ms/step - loss: 0.0572 - precision: 0.8303 - recall: 0.4950 - auc: 0.9317 - f1_score: 0.5590 - specificity_at_sensitivity: 0.9841 - mean_io_u: 0.4375 - val_loss: 0.1025 - val_precision: 0.4468 - val_recall: 0.3684 - val_auc: 0.8141 - val_f1_score: 0.4167 - val_specificity_at_sensitivity: 0.8797 - val_mean_io_u: 0.4375
# Epoch 52/100
# 114/114 [==============================] - 40s 348ms/step - loss: 0.0558 - precision: 0.8282 - recall: 0.5039 - auc: 0.9314 - f1_score: 0.5610 - specificity_at_sensitivity: 0.9849 - mean_io_u: 0.4375 - val_loss: 0.1029 - val_precision: 0.4235 - val_recall: 0.3158 - val_auc: 0.8188 - val_f1_score: 0.3723 - val_specificity_at_sensitivity: 0.8747 - val_mean_io_u: 0.4375
# Epoch 53/100
# 114/114 [==============================] - 39s 345ms/step - loss: 0.0561 - precision: 0.8491 - recall: 0.4950 - auc: 0.9336 - f1_score: 0.5660 - specificity_at_sensitivity: 0.9868 - mean_io_u: 0.4375 - val_loss: 0.0831 - val_precision: 0.5732 - val_recall: 0.4123 - val_auc: 0.8459 - val_f1_score: 0.5000 - val_specificity_at_sensitivity: 0.9336 - val_mean_io_u: 0.4375
# Epoch 54/100
# 114/114 [==============================] - 38s 335ms/step - loss: 0.0533 - precision: 0.8552 - recall: 0.5457 - auc: 0.9364 - f1_score: 0.6031 - specificity_at_sensitivity: 0.9901 - mean_io_u: 0.4375 - val_loss: 0.1128 - val_precision: 0.4111 - val_recall: 0.3246 - val_auc: 0.7603 - val_f1_score: 0.3422 - val_specificity_at_sensitivity: 0.8183 - val_mean_io_u: 0.4375
# Epoch 55/100
# 114/114 [==============================] - 38s 334ms/step - loss: 0.0543 - precision: 0.8497 - recall: 0.5226 - auc: 0.9368 - f1_score: 0.5751 - specificity_at_sensitivity: 0.9881 - mean_io_u: 0.4375 - val_loss: 0.0903 - val_precision: 0.5172 - val_recall: 0.3947 - val_auc: 0.8384 - val_f1_score: 0.4667 - val_specificity_at_sensitivity: 0.9085 - val_mean_io_u: 0.4375
# Epoch 56/100
# 114/114 [==============================] - 38s 336ms/step - loss: 0.0550 - precision: 0.8232 - recall: 0.5072 - auc: 0.9314 - f1_score: 0.5818 - specificity_at_sensitivity: 0.9860 - mean_io_u: 0.4375 - val_loss: 0.0920 - val_precision: 0.5217 - val_recall: 0.3158 - val_auc: 0.8173 - val_f1_score: 0.3681 - val_specificity_at_sensitivity: 0.8810 - val_mean_io_u: 0.4375
# Epoch 57/100
# 114/114 [==============================] - 40s 349ms/step - loss: 0.0520 - precision: 0.8576 - recall: 0.5501 - auc: 0.9396 - f1_score: 0.6232 - specificity_at_sensitivity: 0.9921 - mean_io_u: 0.4375 - val_loss: 0.0973 - val_precision: 0.5366 - val_recall: 0.3860 - val_auc: 0.8156 - val_f1_score: 0.3820 - val_specificity_at_sensitivity: 0.8885 - val_mean_io_u: 0.4375
# Epoch 58/100
# 114/114 [==============================] - 40s 347ms/step - loss: 0.0528 - precision: 0.8510 - recall: 0.5468 - auc: 0.9380 - f1_score: 0.5988 - specificity_at_sensitivity: 0.9895 - mean_io_u: 0.4375 - val_loss: 0.1014 - val_precision: 0.4886 - val_recall: 0.3772 - val_auc: 0.7792 - val_f1_score: 0.4420 - val_specificity_at_sensitivity: 0.8697 - val_mean_io_u: 0.4375
# Epoch 59/100
# 114/114 [==============================] - 38s 337ms/step - loss: 0.0516 - precision: 0.8711 - recall: 0.5501 - auc: 0.9444 - f1_score: 0.6051 - specificity_at_sensitivity: 0.9901 - mean_io_u: 0.4375 - val_loss: 0.0933 - val_precision: 0.4824 - val_recall: 0.3596 - val_auc: 0.8262 - val_f1_score: 0.4246 - val_specificity_at_sensitivity: 0.9035 - val_mean_io_u: 0.4375
# Epoch 60/100
# 114/114 [==============================] - 38s 337ms/step - loss: 0.0507 - precision: 0.8583 - recall: 0.5600 - auc: 0.9433 - f1_score: 0.6311 - specificity_at_sensitivity: 0.9923 - mean_io_u: 0.4375 - val_loss: 0.0949 - val_precision: 0.5227 - val_recall: 0.4035 - val_auc: 0.8333 - val_f1_score: 0.4301 - val_specificity_at_sensitivity: 0.9073 - val_mean_io_u: 0.4375
# Epoch 61/100
# 114/114 [==============================] - 38s 337ms/step - loss: 0.0509 - precision: 0.8499 - recall: 0.5732 - auc: 0.9443 - f1_score: 0.6328 - specificity_at_sensitivity: 0.9915 - mean_io_u: 0.4375 - val_loss: 0.0901 - val_precision: 0.5256 - val_recall: 0.3596 - val_auc: 0.8336 - val_f1_score: 0.4270 - val_specificity_at_sensitivity: 0.9160 - val_mean_io_u: 0.4375
# Epoch 62/100
# 114/114 [==============================] - 40s 351ms/step - loss: 0.0510 - precision: 0.8455 - recall: 0.5600 - auc: 0.9413 - f1_score: 0.6351 - specificity_at_sensitivity: 0.9925 - mean_io_u: 0.4375 - val_loss: 0.0900 - val_precision: 0.5714 - val_recall: 0.3509 - val_auc: 0.8225 - val_f1_score: 0.4046 - val_specificity_at_sensitivity: 0.9123 - val_mean_io_u: 0.4375
# Epoch 63/100
# 114/114 [==============================] - 39s 341ms/step - loss: 0.0498 - precision: 0.8581 - recall: 0.5853 - auc: 0.9478 - f1_score: 0.6352 - specificity_at_sensitivity: 0.9920 - mean_io_u: 0.4375 - val_loss: 0.1039 - val_precision: 0.4375 - val_recall: 0.3070 - val_auc: 0.7873 - val_f1_score: 0.3275 - val_specificity_at_sensitivity: 0.8847 - val_mean_io_u: 0.4375
# Epoch 64/100
# 114/114 [==============================] - 39s 338ms/step - loss: 0.0494 - precision: 0.8586 - recall: 0.5743 - auc: 0.9455 - f1_score: 0.6444 - specificity_at_sensitivity: 0.9929 - mean_io_u: 0.4375 - val_loss: 0.0912 - val_precision: 0.5000 - val_recall: 0.3509 - val_auc: 0.8415 - val_f1_score: 0.4045 - val_specificity_at_sensitivity: 0.9060 - val_mean_io_u: 0.4375
# Epoch 65/100
# 114/114 [==============================] - 39s 338ms/step - loss: 0.0497 - precision: 0.8698 - recall: 0.5512 - auc: 0.9475 - f1_score: 0.6309 - specificity_at_sensitivity: 0.9929 - mean_io_u: 0.4375 - val_loss: 0.1063 - val_precision: 0.4085 - val_recall: 0.2544 - val_auc: 0.7713 - val_f1_score: 0.2771 - val_specificity_at_sensitivity: 0.8471 - val_mean_io_u: 0.4375
# Epoch 66/100
# 114/114 [==============================] - 38s 338ms/step - loss: 0.0477 - precision: 0.8685 - recall: 0.5886 - auc: 0.9488 - f1_score: 0.6539 - specificity_at_sensitivity: 0.9943 - mean_io_u: 0.4375 - val_loss: 0.0836 - val_precision: 0.5696 - val_recall: 0.3947 - val_auc: 0.8487 - val_f1_score: 0.4835 - val_specificity_at_sensitivity: 0.9261 - val_mean_io_u: 0.4375
# Epoch 67/100
# 114/114 [==============================] - 41s 356ms/step - loss: 0.0488 - precision: 0.8702 - recall: 0.5677 - auc: 0.9460 - f1_score: 0.6366 - specificity_at_sensitivity: 0.9929 - mean_io_u: 0.4375 - val_loss: 0.0975 - val_precision: 0.4767 - val_recall: 0.3596 - val_auc: 0.8475 - val_f1_score: 0.3978 - val_specificity_at_sensitivity: 0.8810 - val_mean_io_u: 0.4375
# Epoch 68/100
# 114/114 [==============================] - 40s 347ms/step - loss: 0.0492 - precision: 0.8644 - recall: 0.5820 - auc: 0.9479 - f1_score: 0.6352 - specificity_at_sensitivity: 0.9926 - mean_io_u: 0.4375 - val_loss: 0.0811 - val_precision: 0.6341 - val_recall: 0.4561 - val_auc: 0.8426 - val_f1_score: 0.4918 - val_specificity_at_sensitivity: 0.9486 - val_mean_io_u: 0.4375
# Epoch 69/100
# 114/114 [==============================] - 38s 336ms/step - loss: 0.0471 - precision: 0.8652 - recall: 0.5930 - auc: 0.9526 - f1_score: 0.6521 - specificity_at_sensitivity: 0.9928 - mean_io_u: 0.4375 - val_loss: 0.0914 - val_precision: 0.5176 - val_recall: 0.3860 - val_auc: 0.8406 - val_f1_score: 0.4216 - val_specificity_at_sensitivity: 0.8897 - val_mean_io_u: 0.4375
# Epoch 70/100
# 114/114 [==============================] - 38s 338ms/step - loss: 0.0462 - precision: 0.8716 - recall: 0.5974 - auc: 0.9511 - f1_score: 0.6700 - specificity_at_sensitivity: 0.9954 - mean_io_u: 0.4375 - val_loss: 0.0857 - val_precision: 0.5465 - val_recall: 0.4123 - val_auc: 0.8553 - val_f1_score: 0.4409 - val_specificity_at_sensitivity: 0.9361 - val_mean_io_u: 0.4375
# Epoch 71/100
# 114/114 [==============================] - 38s 338ms/step - loss: 0.0454 - precision: 0.8693 - recall: 0.6073 - auc: 0.9541 - f1_score: 0.6760 - specificity_at_sensitivity: 0.9950 - mean_io_u: 0.4375 - val_loss: 0.0852 - val_precision: 0.6265 - val_recall: 0.4561 - val_auc: 0.8382 - val_f1_score: 0.5185 - val_specificity_at_sensitivity: 0.9273 - val_mean_io_u: 0.4375
# Epoch 72/100
# 114/114 [==============================] - 41s 357ms/step - loss: 0.0461 - precision: 0.8659 - recall: 0.6040 - auc: 0.9522 - f1_score: 0.6615 - specificity_at_sensitivity: 0.9940 - mean_io_u: 0.4375 - val_loss: 0.0857 - val_precision: 0.5824 - val_recall: 0.4649 - val_auc: 0.8315 - val_f1_score: 0.5053 - val_specificity_at_sensitivity: 0.9386 - val_mean_io_u: 0.4375
# Epoch 73/100
# 114/114 [==============================] - 39s 340ms/step - loss: 0.0449 - precision: 0.8781 - recall: 0.6183 - auc: 0.9555 - f1_score: 0.6746 - specificity_at_sensitivity: 0.9962 - mean_io_u: 0.4375 - val_loss: 0.0904 - val_precision: 0.5333 - val_recall: 0.4211 - val_auc: 0.8493 - val_f1_score: 0.4742 - val_specificity_at_sensitivity: 0.9211 - val_mean_io_u: 0.4375
# Epoch 74/100
# 114/114 [==============================] - 38s 338ms/step - loss: 0.0451 - precision: 0.8729 - recall: 0.6271 - auc: 0.9544 - f1_score: 0.6868 - specificity_at_sensitivity: 0.9942 - mean_io_u: 0.4375 - val_loss: 0.0857 - val_precision: 0.5844 - val_recall: 0.3947 - val_auc: 0.8315 - val_f1_score: 0.4294 - val_specificity_at_sensitivity: 0.9373 - val_mean_io_u: 0.4375
# Epoch 75/100
# 114/114 [==============================] - 39s 340ms/step - loss: 0.0446 - precision: 0.8700 - recall: 0.6183 - auc: 0.9566 - f1_score: 0.6754 - specificity_at_sensitivity: 0.9943 - mean_io_u: 0.4375 - val_loss: 0.0996 - val_precision: 0.5000 - val_recall: 0.3684 - val_auc: 0.8063 - val_f1_score: 0.3913 - val_specificity_at_sensitivity: 0.8847 - val_mean_io_u: 0.4375
# Epoch 76/100
# 114/114 [==============================] - 40s 352ms/step - loss: 0.0431 - precision: 0.8909 - recall: 0.6469 - auc: 0.9574 - f1_score: 0.6932 - specificity_at_sensitivity: 0.9953 - mean_io_u: 0.4375 - val_loss: 0.0886 - val_precision: 0.5217 - val_recall: 0.4211 - val_auc: 0.8278 - val_f1_score: 0.5000 - val_specificity_at_sensitivity: 0.9286 - val_mean_io_u: 0.4375
# Epoch 77/100
# 114/114 [==============================] - 40s 347ms/step - loss: 0.0413 - precision: 0.8964 - recall: 0.6667 - auc: 0.9606 - f1_score: 0.7095 - specificity_at_sensitivity: 0.9965 - mean_io_u: 0.4375 - val_loss: 0.1015 - val_precision: 0.4800 - val_recall: 0.4211 - val_auc: 0.8131 - val_f1_score: 0.4388 - val_specificity_at_sensitivity: 0.8985 - val_mean_io_u: 0.4375
# Epoch 78/100
# 114/114 [==============================] - 38s 336ms/step - loss: 0.0417 - precision: 0.8791 - recall: 0.6480 - auc: 0.9593 - f1_score: 0.7149 - specificity_at_sensitivity: 0.9962 - mean_io_u: 0.4375 - val_loss: 0.0906 - val_precision: 0.5647 - val_recall: 0.4211 - val_auc: 0.8332 - val_f1_score: 0.4492 - val_specificity_at_sensitivity: 0.9298 - val_mean_io_u: 0.4375
# Epoch 79/100
# 114/114 [==============================] - 39s 339ms/step - loss: 0.0421 - precision: 0.8685 - recall: 0.6469 - auc: 0.9601 - f1_score: 0.7030 - specificity_at_sensitivity: 0.9959 - mean_io_u: 0.4375 - val_loss: 0.0976 - val_precision: 0.4783 - val_recall: 0.3860 - val_auc: 0.8348 - val_f1_score: 0.3804 - val_specificity_at_sensitivity: 0.8885 - val_mean_io_u: 0.4375
# Epoch 80/100
# 114/114 [==============================] - 38s 338ms/step - loss: 0.0398 - precision: 0.8870 - recall: 0.6733 - auc: 0.9633 - f1_score: 0.7355 - specificity_at_sensitivity: 0.9973 - mean_io_u: 0.4375 - val_loss: 0.1104 - val_precision: 0.4624 - val_recall: 0.3772 - val_auc: 0.7872 - val_f1_score: 0.4242 - val_specificity_at_sensitivity: 0.8960 - val_mean_io_u: 0.4375
# Epoch 81/100
# 114/114 [==============================] - 40s 356ms/step - loss: 0.0408 - precision: 0.8874 - recall: 0.6678 - auc: 0.9630 - f1_score: 0.7153 - specificity_at_sensitivity: 0.9965 - mean_io_u: 0.4375 - val_loss: 0.0950 - val_precision: 0.5385 - val_recall: 0.4298 - val_auc: 0.8252 - val_f1_score: 0.4767 - val_specificity_at_sensitivity: 0.9048 - val_mean_io_u: 0.4375
# Epoch 82/100
# 114/114 [==============================] - 40s 347ms/step - loss: 0.0421 - precision: 0.8785 - recall: 0.6601 - auc: 0.9584 - f1_score: 0.7130 - specificity_at_sensitivity: 0.9958 - mean_io_u: 0.4375 - val_loss: 0.0795 - val_precision: 0.6395 - val_recall: 0.4825 - val_auc: 0.8555 - val_f1_score: 0.5217 - val_specificity_at_sensitivity: 0.9612 - val_mean_io_u: 0.4375
# Epoch 83/100
# 114/114 [==============================] - 38s 337ms/step - loss: 0.0396 - precision: 0.8935 - recall: 0.6920 - auc: 0.9637 - f1_score: 0.7319 - specificity_at_sensitivity: 0.9972 - mean_io_u: 0.4375 - val_loss: 0.1047 - val_precision: 0.5000 - val_recall: 0.4211 - val_auc: 0.8108 - val_f1_score: 0.4061 - val_specificity_at_sensitivity: 0.8922 - val_mean_io_u: 0.4375
# Epoch 84/100
# 114/114 [==============================] - 39s 338ms/step - loss: 0.0391 - precision: 0.8947 - recall: 0.6821 - auc: 0.9669 - f1_score: 0.7274 - specificity_at_sensitivity: 0.9975 - mean_io_u: 0.4375 - val_loss: 0.0959 - val_precision: 0.5385 - val_recall: 0.4298 - val_auc: 0.8067 - val_f1_score: 0.4694 - val_specificity_at_sensitivity: 0.9185 - val_mean_io_u: 0.4375
# Epoch 85/100
# 114/114 [==============================] - 38s 335ms/step - loss: 0.0392 - precision: 0.8882 - recall: 0.6733 - auc: 0.9669 - f1_score: 0.7209 - specificity_at_sensitivity: 0.9972 - mean_io_u: 0.4375 - val_loss: 0.0951 - val_precision: 0.5444 - val_recall: 0.4298 - val_auc: 0.8038 - val_f1_score: 0.4409 - val_specificity_at_sensitivity: 0.9135 - val_mean_io_u: 0.4375
# Epoch 86/100
# 114/114 [==============================] - 41s 356ms/step - loss: 0.0400 - precision: 0.8923 - recall: 0.6656 - auc: 0.9638 - f1_score: 0.7224 - specificity_at_sensitivity: 0.9959 - mean_io_u: 0.4375 - val_loss: 0.0887 - val_precision: 0.5909 - val_recall: 0.4561 - val_auc: 0.8443 - val_f1_score: 0.4813 - val_specificity_at_sensitivity: 0.9261 - val_mean_io_u: 0.4375
# Epoch 87/100
# 114/114 [==============================] - 39s 344ms/step - loss: 0.0409 - precision: 0.8803 - recall: 0.6634 - auc: 0.9631 - f1_score: 0.7217 - specificity_at_sensitivity: 0.9948 - mean_io_u: 0.4375 - val_loss: 0.1171 - val_precision: 0.4500 - val_recall: 0.3947 - val_auc: 0.7355 - val_f1_score: 0.4020 - val_specificity_at_sensitivity: 0.8647 - val_mean_io_u: 0.4375
# Epoch 88/100
# 114/114 [==============================] - 38s 338ms/step - loss: 0.0383 - precision: 0.9029 - recall: 0.6854 - auc: 0.9654 - f1_score: 0.7219 - specificity_at_sensitivity: 0.9976 - mean_io_u: 0.4375 - val_loss: 0.0999 - val_precision: 0.4839 - val_recall: 0.3947 - val_auc: 0.8175 - val_f1_score: 0.4388 - val_specificity_at_sensitivity: 0.8885 - val_mean_io_u: 0.4375
# Epoch 89/100
# 114/114 [==============================] - 39s 339ms/step - loss: 0.0383 - precision: 0.8957 - recall: 0.6898 - auc: 0.9670 - f1_score: 0.7447 - specificity_at_sensitivity: 0.9970 - mean_io_u: 0.4375 - val_loss: 0.0934 - val_precision: 0.5591 - val_recall: 0.4561 - val_auc: 0.8136 - val_f1_score: 0.4873 - val_specificity_at_sensitivity: 0.9261 - val_mean_io_u: 0.4375
# Epoch 90/100
# 114/114 [==============================] - 39s 339ms/step - loss: 0.0384 - precision: 0.8940 - recall: 0.6865 - auc: 0.9661 - f1_score: 0.7384 - specificity_at_sensitivity: 0.9975 - mean_io_u: 0.4375 - val_loss: 0.0937 - val_precision: 0.5054 - val_recall: 0.4123 - val_auc: 0.8244 - val_f1_score: 0.4468 - val_specificity_at_sensitivity: 0.9236 - val_mean_io_u: 0.4375
# Epoch 91/100
# 114/114 [==============================] - 41s 358ms/step - loss: 0.0368 - precision: 0.8975 - recall: 0.6843 - auc: 0.9697 - f1_score: 0.7389 - specificity_at_sensitivity: 0.9976 - mean_io_u: 0.4375 - val_loss: 0.1275 - val_precision: 0.4074 - val_recall: 0.3860 - val_auc: 0.7351 - val_f1_score: 0.3774 - val_specificity_at_sensitivity: 0.8421 - val_mean_io_u: 0.4375
# Epoch 92/100
# 114/114 [==============================] - 39s 341ms/step - loss: 0.0378 - precision: 0.9053 - recall: 0.6942 - auc: 0.9673 - f1_score: 0.7455 - specificity_at_sensitivity: 0.9972 - mean_io_u: 0.4375 - val_loss: 0.0885 - val_precision: 0.5824 - val_recall: 0.4649 - val_auc: 0.8248 - val_f1_score: 0.4787 - val_specificity_at_sensitivity: 0.9449 - val_mean_io_u: 0.4375
# Epoch 93/100
# 114/114 [==============================] - 39s 339ms/step - loss: 0.0366 - precision: 0.9108 - recall: 0.6854 - auc: 0.9669 - f1_score: 0.7457 - specificity_at_sensitivity: 0.9983 - mean_io_u: 0.4375 - val_loss: 0.0974 - val_precision: 0.5000 - val_recall: 0.3596 - val_auc: 0.7938 - val_f1_score: 0.4222 - val_specificity_at_sensitivity: 0.8910 - val_mean_io_u: 0.4375
# Epoch 94/100
# 114/114 [==============================] - 38s 337ms/step - loss: 0.0353 - precision: 0.9087 - recall: 0.7228 - auc: 0.9710 - f1_score: 0.7570 - specificity_at_sensitivity: 0.9976 - mean_io_u: 0.4375 - val_loss: 0.0873 - val_precision: 0.5930 - val_recall: 0.4474 - val_auc: 0.8176 - val_f1_score: 0.5027 - val_specificity_at_sensitivity: 0.9373 - val_mean_io_u: 0.4375
# Epoch 95/100
# 114/114 [==============================] - 40s 352ms/step - loss: 0.0351 - precision: 0.9141 - recall: 0.7261 - auc: 0.9699 - f1_score: 0.7631 - specificity_at_sensitivity: 0.9978 - mean_io_u: 0.4375 - val_loss: 0.1162 - val_precision: 0.4369 - val_recall: 0.3947 - val_auc: 0.7664 - val_f1_score: 0.4020 - val_specificity_at_sensitivity: 0.8897 - val_mean_io_u: 0.4375
# Epoch 96/100
# 114/114 [==============================] - 41s 359ms/step - loss: 0.0350 - precision: 0.9189 - recall: 0.7228 - auc: 0.9707 - f1_score: 0.7675 - specificity_at_sensitivity: 0.9986 - mean_io_u: 0.4375 - val_loss: 0.0994 - val_precision: 0.5111 - val_recall: 0.4035 - val_auc: 0.7940 - val_f1_score: 0.4211 - val_specificity_at_sensitivity: 0.8972 - val_mean_io_u: 0.4375
# Epoch 97/100
# 114/114 [==============================] - 39s 340ms/step - loss: 0.0337 - precision: 0.9178 - recall: 0.7250 - auc: 0.9732 - f1_score: 0.7796 - specificity_at_sensitivity: 0.9989 - mean_io_u: 0.4375 - val_loss: 0.0978 - val_precision: 0.5119 - val_recall: 0.3772 - val_auc: 0.8229 - val_f1_score: 0.4348 - val_specificity_at_sensitivity: 0.8922 - val_mean_io_u: 0.4375
# Epoch 98/100
# 114/114 [==============================] - 39s 339ms/step - loss: 0.0343 - precision: 0.9090 - recall: 0.7250 - auc: 0.9733 - f1_score: 0.7639 - specificity_at_sensitivity: 0.9981 - mean_io_u: 0.4375 - val_loss: 0.0979 - val_precision: 0.5258 - val_recall: 0.4474 - val_auc: 0.8098 - val_f1_score: 0.4848 - val_specificity_at_sensitivity: 0.9148 - val_mean_io_u: 0.4375
# Epoch 99/100
# 114/114 [==============================] - 38s 338ms/step - loss: 0.0321 - precision: 0.9240 - recall: 0.7492 - auc: 0.9756 - f1_score: 0.7837 - specificity_at_sensitivity: 0.9987 - mean_io_u: 0.4375 - val_loss: 0.0937 - val_precision: 0.5647 - val_recall: 0.4211 - val_auc: 0.8209 - val_f1_score: 0.4492 - val_specificity_at_sensitivity: 0.9085 - val_mean_io_u: 0.4375
# Epoch 100/100
# 114/114 [==============================] - 41s 361ms/step - loss: 0.0352 - precision: 0.8971 - recall: 0.7195 - auc: 0.9713 - f1_score: 0.7569 - specificity_at_sensitivity: 0.9983 - mean_io_u: 0.4375 - val_loss: 0.1003 - val_precision: 0.4848 - val_recall: 0.4211 - val_auc: 0.8223 - val_f1_score: 0.4608 - val_specificity_at_sensitivity: 0.9023 - val_mean_io_u: 0.4375
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## **모델 테스트**

# %%
temp_y = enc.fit_transform(y_test).toarray()
y_test = temp_y

test_metrics = model.evaluate(x_test, y_test)
print("Test Metrics:", test_metrics)
print(hist.history.keys())
# Out:
# 4/4 [==============================] - 1s 217ms/step - loss: 0.1092 - precision: 0.4124 - recall: 0.3509 - auc: 0.7973 - f1_score: 0.3795 - specificity_at_sensitivity: 0.8734 - mean_io_u: 0.4375
# Test Metrics: [0.10922840982675552, 0.41237112879753113, 0.35087719559669495, 0.7973441481590271, 0.37948718667030334, 0.8734335899353027, 0.4375]
# dict_keys(['loss', 'precision', 'recall', 'auc', 'f1_score', 'specificity_at_sensitivity', 'mean_io_u', 'val_loss', 'val_precision', 'val_recall', 'val_auc', 'val_f1_score', 'val_specificity_at_sensitivity', 'val_mean_io_u'])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'],'y',label='train loss')
loss_ax.plot(hist.history['val_loss'],'r',label='val loss')
acc_ax.plot(hist.history['auc'],'b',label='train acc')
acc_ax.plot(hist.history['val_auc'],'g',label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')
plt.show()

# %%
print('##### Test Result #####')
print('loss : ',str(test_metrics[0]))
print('Accuracy : ',str(test_metrics[1]))
# Out:
# ##### Test Result #####
# loss :  0.10922840982675552
# Accuracy :  0.41237112879753113
